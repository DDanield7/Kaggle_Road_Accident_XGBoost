# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt 
import xgboost as xgb #use xgb as algorthm model
from xgboost import XGBRegressor #use xgb regressor because we want to predict continuous numerical value
from sklearn.preprocessing import LabelEncoder #encode all categorical and boolean feature
import optuna # hyperparameter tuning using optuna
from sklearn.model_selection import cross_val_score #to evaluate model
from sklearn.model_selection import StratifiedKFold #to perform k-fold

# %%
data_train = pd.read_csv('./train.csv')
data_test = pd.read_csv('./test.csv')

# %%
#divide dataset into 4
y_train = data_train['accident_risk'] #target train
train_ids = data_train['id'] #target train id
test_ids = data_test['id'] #target test id
train = data_train.drop(['accident_risk','id'],axis=1) #train feature 
test = data_test.drop(['id'],axis=1) # test feature

# %%
X_train = train.copy()
X_test = test.copy()

# %%
#feature encoding

#first select categorical,object and boolean column
cat_col = X_train.select_dtypes(['object','bool']).columns

# %%
#label encode

#in test data we use only transform, to prevent inconsistency, like example: in training blue encoded as 1,
#so when in test dataset the blue also encoded as 1 not 0 or other number.
for col in cat_col:
    le = LabelEncoder()
    X_train[col] = le.fit_transform(X_train[col].astype(str))
    X_test[col] = le.transform(X_test[col].astype(str))

# %%
def objective(trial):

    #optuna will search the best output given a specified range of numbers
    xgb_params = {
        'objective': 'reg:squarederror',
        'max_bin': trial.suggest_int('max_bin',100,600),
        'learning_rate': trial.suggest_float('learning_rate',0.01,0.1),
        'max_depth': trial.suggest_int('max_depth',1,10),
        'min_child_weight': trial.suggest_int('min_child_weight',1,10),
        'subsample': trial.suggest_float('subsample',0.1,1),
        'colsample_bytree': trial.suggest_float('colsample_bytree',0.1,1),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel',0.1,1),
        'colsample_bynode': trial.suggest_float('colsample_bynode',0.1,1),
        'reg_alpha': trial.suggest_float('reg_alpha',0.1,1),
        'reg_lambda': trial.suggest_float('reg_lambda',0.1,1),
        'gamma': trial.suggest_float('gamma',0.1,1),
        'max_delta_step': trial.suggest_int('max_delta_step',0,10),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight',0.1,1)
    }

    model = XGBRegressor(**xgb_params,tree_method='hist',device='cuda') #configure xgbregressor model

    #evaluate model
    score = cross_val_score(model,X_train,y_train,cv=7,scoring='neg_mean_absolute_error')#cross_val_score do .fit() internally
    mae = -score.mean()
    return mae

# %%
#configure optuna
study = optuna.create_study(study_name='xgboost_optuna_roadaccident_comp',direction='minimize')
study.optimize(objective,n_trials=100,show_progress_bar=True,n_jobs=-1) #njobs -1 to run on all cores to speed up process
# Out:
# [I 2025-11-26 15:59:09,882] A new study created in memory with name: xgboost_optuna_roadaccident_comp
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-11-26 15:59:37,084] Trial 4 finished with value: 0.058268797219213096 and parameters: {'max_bin': 213, 'learning_rate': 0.09347719881990574, 'max_depth': 1, 'min_child_weight': 9, 'subsample': 0.2597858561641704, 'colsample_bytree': 0.42738351614761105, 'colsample_bylevel': 0.7100252319310371, 'colsample_bynode': 0.7750520660361881, 'reg_alpha': 0.20525743484586445, 'reg_lambda': 0.2623039572248737, 'gamma': 0.2806549194213439, 'max_delta_step': 10, 'scale_pos_weight': 0.44274758840825346}. Best is trial 4 with value: 0.058268797219213096.
# [I 2025-11-26 15:59:52,964] Trial 0 finished with value: 0.06654606655315733 and parameters: {'max_bin': 102, 'learning_rate': 0.07263713998269804, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.8095788193688069, 'colsample_bytree': 0.555356779843612, 'colsample_bylevel': 0.12491783476989698, 'colsample_bynode': 0.8084693944007352, 'reg_alpha': 0.3767640254501896, 'reg_lambda': 0.8355268951511426, 'gamma': 0.5901376836188226, 'max_delta_step': 2, 'scale_pos_weight': 0.43814610037500545}. Best is trial 4 with value: 0.058268797219213096.
# [I 2025-11-26 15:59:53,064] Trial 1 finished with value: 0.06831155725238298 and parameters: {'max_bin': 326, 'learning_rate': 0.07569724386472819, 'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.5878518297689678, 'colsample_bytree': 0.3335303656800793, 'colsample_bylevel': 0.7546402766208412, 'colsample_bynode': 0.1697420489112375, 'reg_alpha': 0.6063320281012805, 'reg_lambda': 0.30759497811139647, 'gamma': 0.5720961605351597, 'max_delta_step': 8, 'scale_pos_weight': 0.22800513584068388}. Best is trial 4 with value: 0.058268797219213096.
# [I 2025-11-26 15:59:58,257] Trial 7 finished with value: 0.06265946089171208 and parameters: {'max_bin': 137, 'learning_rate': 0.09234687706905188, 'max_depth': 10, 'min_child_weight': 9, 'subsample': 0.7769908571914802, 'colsample_bytree': 0.4508540278780233, 'colsample_bylevel': 0.53860775710041, 'colsample_bynode': 0.9648102462972381, 'reg_alpha': 0.27715603404929534, 'reg_lambda': 0.7471807206301334, 'gamma': 0.4146936852677541, 'max_delta_step': 1, 'scale_pos_weight': 0.38922713846646095}. Best is trial 4 with value: 0.058268797219213096.
# [I 2025-11-26 16:00:00,190] Trial 2 finished with value: 0.0945648588706139 and parameters: {'max_bin': 311, 'learning_rate': 0.0323833995355251, 'max_depth': 9, 'min_child_weight': 1, 'subsample': 0.43713298671489387, 'colsample_bytree': 0.22222614224267673, 'colsample_bylevel': 0.3095421056941317, 'colsample_bynode': 0.5880687934148575, 'reg_alpha': 0.5961998729657967, 'reg_lambda': 0.10208154149155454, 'gamma': 0.6076270245915383, 'max_delta_step': 3, 'scale_pos_weight': 0.5923610904417386}. Best is trial 4 with value: 0.058268797219213096.
# [I 2025-11-26 16:00:01,815] Trial 3 finished with value: 0.11209981356843386 and parameters: {'max_bin': 282, 'learning_rate': 0.011760737634627769, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.4932217874579625, 'colsample_bytree': 0.44342968666084925, 'colsample_bylevel': 0.721253139854617, 'colsample_bynode': 0.3995194823279974, 'reg_alpha': 0.3742849934853799, 'reg_lambda': 0.7955127970863515, 'gamma': 0.8648611651594454, 'max_delta_step': 1, 'scale_pos_weight': 0.9114998902512589}. Best is trial 4 with value: 0.058268797219213096.
# [I 2025-11-26 16:00:06,587] Trial 6 finished with value: 0.08115089194368318 and parameters: {'max_bin': 504, 'learning_rate': 0.043172523215841675, 'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.6970591061789235, 'colsample_bytree': 0.3658202833769766, 'colsample_bylevel': 0.25043842125497184, 'colsample_bynode': 0.9010713272689247, 'reg_alpha': 0.13957352663916445, 'reg_lambda': 0.8068438524970372, 'gamma': 0.33841318112659624, 'max_delta_step': 9, 'scale_pos_weight': 0.45512301548871636}. Best is trial 4 with value: 0.058268797219213096.
# [I 2025-11-26 16:00:14,325] Trial 8 finished with value: 0.11790295504343788 and parameters: {'max_bin': 131, 'learning_rate': 0.01340720737658877, 'max_depth': 4, 'min_child_weight': 9, 'subsample': 0.22398745399269715, 'colsample_bytree': 0.2868156625584751, 'colsample_bylevel': 0.4349494734258965, 'colsample_bynode': 0.42151052389439436, 'reg_alpha': 0.7923382853535333, 'reg_lambda': 0.5122645230434906, 'gamma': 0.5522988370634587, 'max_delta_step': 8, 'scale_pos_weight': 0.29546212009877376}. Best is trial 4 with value: 0.058268797219213096.
# [I 2025-11-26 16:00:25,089] Trial 10 finished with value: 0.05873581593983769 and parameters: {'max_bin': 406, 'learning_rate': 0.05237212486915467, 'max_depth': 2, 'min_child_weight': 7, 'subsample': 0.7288359399008684, 'colsample_bytree': 0.7172602316472001, 'colsample_bylevel': 0.47733167708089064, 'colsample_bynode': 0.7676646493371294, 'reg_alpha': 0.696099070505702, 'reg_lambda': 0.814501959659741, 'gamma': 0.6983877044077158, 'max_delta_step': 4, 'scale_pos_weight': 0.16568292830760054}. Best is trial 4 with value: 0.058268797219213096.
# [I 2025-11-26 16:00:34,280] Trial 13 finished with value: 0.08980753868846572 and parameters: {'max_bin': 421, 'learning_rate': 0.040766383814083096, 'max_depth': 2, 'min_child_weight': 3, 'subsample': 0.21570266652990247, 'colsample_bytree': 0.8221910863012958, 'colsample_bylevel': 0.9062343648678902, 'colsample_bynode': 0.1330912796490335, 'reg_alpha': 0.8359770162030631, 'reg_lambda': 0.6762211887495988, 'gamma': 0.21435638096245546, 'max_delta_step': 0, 'scale_pos_weight': 0.3801956871904928}. Best is trial 4 with value: 0.058268797219213096.
# [I 2025-11-26 16:00:39,213] Trial 12 finished with value: 0.09398371718687851 and parameters: {'max_bin': 377, 'learning_rate': 0.02772961018749738, 'max_depth': 3, 'min_child_weight': 10, 'subsample': 0.3707206197141596, 'colsample_bytree': 0.6876876845250524, 'colsample_bylevel': 0.875225411207956, 'colsample_bynode': 0.23666579206558336, 'reg_alpha': 0.6411311657569997, 'reg_lambda': 0.4245737017808139, 'gamma': 0.8408113589351698, 'max_delta_step': 7, 'scale_pos_weight': 0.8435643002764541}. Best is trial 4 with value: 0.058268797219213096.
# [I 2025-11-26 16:00:53,643] Trial 15 finished with value: 0.05558704784415023 and parameters: {'max_bin': 594, 'learning_rate': 0.09765981246754595, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.5908235505800746, 'colsample_bytree': 0.8464604384934292, 'colsample_bylevel': 0.23395199387554122, 'colsample_bynode': 0.15915028479610802, 'reg_alpha': 0.16835460193248122, 'reg_lambda': 0.9295704953691323, 'gamma': 0.5985437352950748, 'max_delta_step': 3, 'scale_pos_weight': 0.8960784920493269}. Best is trial 15 with value: 0.05558704784415023.
# [I 2025-11-26 16:00:59,233] Trial 16 finished with value: 0.0937092773743956 and parameters: {'max_bin': 252, 'learning_rate': 0.03195296762126489, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.19931366923385907, 'colsample_bytree': 0.4125901038050248, 'colsample_bylevel': 0.1381448218846668, 'colsample_bynode': 0.7191881008780966, 'reg_alpha': 0.5894293557569871, 'reg_lambda': 0.2223662554329353, 'gamma': 0.20701556804204047, 'max_delta_step': 2, 'scale_pos_weight': 0.24722298751349034}. Best is trial 15 with value: 0.05558704784415023.
# [I 2025-11-26 16:01:00,126] Trial 17 finished with value: 0.08591197245082942 and parameters: {'max_bin': 224, 'learning_rate': 0.09966057959759048, 'max_depth': 1, 'min_child_weight': 10, 'subsample': 0.9647614136063717, 'colsample_bytree': 0.13376634231488316, 'colsample_bylevel': 0.9949300861544986, 'colsample_bynode': 0.6433345923258587, 'reg_alpha': 0.10136586437352994, 'reg_lambda': 0.35966779314111735, 'gamma': 0.10022134051725945, 'max_delta_step': 6, 'scale_pos_weight': 0.6943191460393838}. Best is trial 15 with value: 0.05558704784415023.
# [I 2025-11-26 16:01:03,942] Trial 18 finished with value: 0.061116322260302454 and parameters: {'max_bin': 230, 'learning_rate': 0.06022910537993515, 'max_depth': 1, 'min_child_weight': 8, 'subsample': 0.9826561242145924, 'colsample_bytree': 0.9975630029552299, 'colsample_bylevel': 0.6367380931801161, 'colsample_bynode': 0.7090447213899964, 'reg_alpha': 0.11825067458962829, 'reg_lambda': 0.9802004229130314, 'gamma': 0.13277912455602314, 'max_delta_step': 5, 'scale_pos_weight': 0.10372860975490332}. Best is trial 15 with value: 0.05558704784415023.
# [I 2025-11-26 16:01:07,127] Trial 11 finished with value: 0.04452176771812045 and parameters: {'max_bin': 379, 'learning_rate': 0.09755613627848767, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.5975910728863895, 'colsample_bytree': 0.9481393265936854, 'colsample_bylevel': 0.8249023369704249, 'colsample_bynode': 0.6280927113730151, 'reg_alpha': 0.21253066817082056, 'reg_lambda': 0.8092634061171021, 'gamma': 0.7813638217863128, 'max_delta_step': 6, 'scale_pos_weight': 0.6626802345549556}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:01:14,961] Trial 9 finished with value: 0.04756532514851086 and parameters: {'max_bin': 578, 'learning_rate': 0.04652875223429374, 'max_depth': 10, 'min_child_weight': 8, 'subsample': 0.45656004326043476, 'colsample_bytree': 0.9397179092399266, 'colsample_bylevel': 0.6911313881975107, 'colsample_bynode': 0.4504731703741497, 'reg_alpha': 0.7939092562462376, 'reg_lambda': 0.143669800989808, 'gamma': 0.8922400533730359, 'max_delta_step': 3, 'scale_pos_weight': 0.8679620408834793}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:01:18,046] Trial 19 finished with value: 0.05110118749168331 and parameters: {'max_bin': 573, 'learning_rate': 0.09558144597760251, 'max_depth': 1, 'min_child_weight': 1, 'subsample': 0.9730175475594773, 'colsample_bytree': 0.9576606801539063, 'colsample_bylevel': 0.6764911254169089, 'colsample_bynode': 0.6491099867776876, 'reg_alpha': 0.10596272559775738, 'reg_lambda': 0.9892857565090062, 'gamma': 0.15914638623917338, 'max_delta_step': 6, 'scale_pos_weight': 0.6807102263948491}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:01:21,857] Trial 20 finished with value: 0.050622474351370315 and parameters: {'max_bin': 580, 'learning_rate': 0.09869384544162735, 'max_depth': 1, 'min_child_weight': 1, 'subsample': 0.9966102599468658, 'colsample_bytree': 0.9272831878922065, 'colsample_bylevel': 0.6559103712999007, 'colsample_bynode': 0.5867326045304208, 'reg_alpha': 0.10137106262157007, 'reg_lambda': 0.9957589982701635, 'gamma': 0.3820933410085974, 'max_delta_step': 6, 'scale_pos_weight': 0.6836359586548353}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:01:40,740] Trial 22 finished with value: 0.06998122226456004 and parameters: {'max_bin': 561, 'learning_rate': 0.08245845009207496, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.10376719248127486, 'colsample_bytree': 0.9902782147877277, 'colsample_bylevel': 0.3578180745782549, 'colsample_bynode': 0.4476623846586168, 'reg_alpha': 0.2693875349574453, 'reg_lambda': 0.5395632150365022, 'gamma': 0.4153259572647754, 'max_delta_step': 10, 'scale_pos_weight': 0.7485361119221818}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:01:47,505] Trial 23 finished with value: 0.06435856953731026 and parameters: {'max_bin': 559, 'learning_rate': 0.08021040146706662, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.5486944883578823, 'colsample_bytree': 0.930598730874243, 'colsample_bylevel': 0.35826424165462845, 'colsample_bynode': 0.42170074778979316, 'reg_alpha': 0.4332305010082059, 'reg_lambda': 0.9936162050388578, 'gamma': 0.7662329242419433, 'max_delta_step': 5, 'scale_pos_weight': 0.7684671870902982}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:01:52,995] Trial 14 finished with value: 0.04849610701907629 and parameters: {'max_bin': 245, 'learning_rate': 0.04426854341111005, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.48241271100253935, 'colsample_bytree': 0.8112609937864301, 'colsample_bylevel': 0.47045464425219885, 'colsample_bynode': 0.8341942975873708, 'reg_alpha': 0.7156208813854423, 'reg_lambda': 0.775374099867605, 'gamma': 0.3907255534004197, 'max_delta_step': 2, 'scale_pos_weight': 0.9623132575708696}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:01:57,824] Trial 21 finished with value: 0.04531003893506667 and parameters: {'max_bin': 569, 'learning_rate': 0.08129287074797245, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.3202392094806051, 'colsample_bytree': 0.9599806885293511, 'colsample_bylevel': 0.6583777153404893, 'colsample_bynode': 0.44528172924579823, 'reg_alpha': 0.2594236156634746, 'reg_lambda': 0.6205579593454722, 'gamma': 0.9977584561702422, 'max_delta_step': 10, 'scale_pos_weight': 0.7366020981117152}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:02:08,095] Trial 26 finished with value: 0.049201860077148406 and parameters: {'max_bin': 478, 'learning_rate': 0.08021541289700593, 'max_depth': 9, 'min_child_weight': 5, 'subsample': 0.3248739161111691, 'colsample_bytree': 0.6805368374419487, 'colsample_bylevel': 0.8524118082716816, 'colsample_bynode': 0.447213251985492, 'reg_alpha': 0.963064215982622, 'reg_lambda': 0.6192937254486542, 'gamma': 0.9843308664016028, 'max_delta_step': 5, 'scale_pos_weight': 0.7766543803658134}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:02:12,237] Trial 24 finished with value: 0.045643354506442434 and parameters: {'max_bin': 482, 'learning_rate': 0.07450397767280714, 'max_depth': 9, 'min_child_weight': 5, 'subsample': 0.3583367158378223, 'colsample_bytree': 0.9838559702065435, 'colsample_bylevel': 0.8093145708137285, 'colsample_bynode': 0.46749331403946215, 'reg_alpha': 0.956860749675862, 'reg_lambda': 0.6315211235829764, 'gamma': 0.9953806523975196, 'max_delta_step': 5, 'scale_pos_weight': 0.7424223549418681}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:02:18,315] Trial 27 finished with value: 0.07812251577508804 and parameters: {'max_bin': 473, 'learning_rate': 0.05683904063754254, 'max_depth': 9, 'min_child_weight': 5, 'subsample': 0.34226024183948534, 'colsample_bytree': 0.6602100683073122, 'colsample_bylevel': 0.8291300907216055, 'colsample_bynode': 0.30649330793526913, 'reg_alpha': 0.9120093368747153, 'reg_lambda': 0.6372209531215597, 'gamma': 0.9805790001841044, 'max_delta_step': 4, 'scale_pos_weight': 0.8293814614873573}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:02:20,877] Trial 25 finished with value: 0.045484927957709816 and parameters: {'max_bin': 467, 'learning_rate': 0.07903229727812935, 'max_depth': 9, 'min_child_weight': 5, 'subsample': 0.399205457194616, 'colsample_bytree': 0.8819313364320759, 'colsample_bylevel': 0.8334971529166321, 'colsample_bynode': 0.4742502215313896, 'reg_alpha': 0.435598109747094, 'reg_lambda': 0.584466360593143, 'gamma': 0.9898539178193, 'max_delta_step': 5, 'scale_pos_weight': 0.7697785404313227}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:02:36,886] Trial 30 finished with value: 0.06936021402392895 and parameters: {'max_bin': 484, 'learning_rate': 0.06268053507771934, 'max_depth': 10, 'min_child_weight': 4, 'subsample': 0.3538568117967867, 'colsample_bytree': 0.7314196442566381, 'colsample_bylevel': 0.8096509404912121, 'colsample_bynode': 0.31224076722505945, 'reg_alpha': 0.9726604566000467, 'reg_lambda': 0.6447209472034906, 'gamma': 0.9770804891465642, 'max_delta_step': 4, 'scale_pos_weight': 0.5663931738379158}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:02:37,571] Trial 5 finished with value: 0.055560030677859244 and parameters: {'max_bin': 591, 'learning_rate': 0.018303554322365197, 'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.8627987832179637, 'colsample_bytree': 0.9001368339720294, 'colsample_bylevel': 0.5995458957197478, 'colsample_bynode': 0.9882410309562631, 'reg_alpha': 0.9503364301909842, 'reg_lambda': 0.35455541256010004, 'gamma': 0.11534254883716522, 'max_delta_step': 6, 'scale_pos_weight': 0.9558336624057936}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:02:45,406] Trial 32 finished with value: 0.06935607039504911 and parameters: {'max_bin': 481, 'learning_rate': 0.06579312222431258, 'max_depth': 6, 'min_child_weight': 3, 'subsample': 0.3492205703085064, 'colsample_bytree': 0.8763728262200033, 'colsample_bylevel': 0.7849500738527935, 'colsample_bynode': 0.26748725986402866, 'reg_alpha': 0.4922700512308834, 'reg_lambda': 0.6343940757383614, 'gamma': 0.9974595939752786, 'max_delta_step': 8, 'scale_pos_weight': 0.5687351151808802}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:02:55,473] Trial 31 finished with value: 0.05123281343466822 and parameters: {'max_bin': 499, 'learning_rate': 0.06614053404108594, 'max_depth': 6, 'min_child_weight': 3, 'subsample': 0.3732930162848995, 'colsample_bytree': 0.8735276694334266, 'colsample_bylevel': 0.8120393364082502, 'colsample_bynode': 0.3051506319376301, 'reg_alpha': 0.4930748404545689, 'reg_lambda': 0.661039802704491, 'gamma': 0.9896251544063351, 'max_delta_step': 4, 'scale_pos_weight': 0.5953192863118659}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:03:17,424] Trial 34 finished with value: 0.04998768039040781 and parameters: {'max_bin': 438, 'learning_rate': 0.06532934354890381, 'max_depth': 6, 'min_child_weight': 3, 'subsample': 0.6441915032280809, 'colsample_bytree': 0.8718657014612445, 'colsample_bylevel': 0.5965887716923524, 'colsample_bynode': 0.5301596744011072, 'reg_alpha': 0.4633531880556202, 'reg_lambda': 0.45080031017587907, 'gamma': 0.7716370618468746, 'max_delta_step': 7, 'scale_pos_weight': 0.6193399043248039}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:03:20,544] Trial 28 finished with value: 0.04472540442098159 and parameters: {'max_bin': 505, 'learning_rate': 0.06362282158697795, 'max_depth': 9, 'min_child_weight': 4, 'subsample': 0.8703270296081236, 'colsample_bytree': 0.8359986840370125, 'colsample_bylevel': 0.8037459650878284, 'colsample_bynode': 0.5215015562683385, 'reg_alpha': 0.9873443829324695, 'reg_lambda': 0.675678999412462, 'gamma': 0.9877472632964748, 'max_delta_step': 6, 'scale_pos_weight': 0.9991950437972743}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16
. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:04:35,285] Trial 40 finished with value: 0.0445707641716501 and parameters: {'max_bin': 529, 'learning_rate': 0.08532767879133779, 'max_depth': 8, 'min_child_weight': 2, 'subsample': 0.8904745358214239, 'colsample_bytree': 0.7678630042379133, 'colsample_bylevel': 0.9160977603865367, 'colsample_bynode': 0.5312476715122656, 'reg_alpha': 0.3308377294253154, 'reg_lambda': 0.8789922242448467, 'gamma': 0.9154021285863057, 'max_delta_step': 7, 'scale_pos_weight': 0.9855156367759501}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:04:35,422] Trial 43 finished with value: 0.045475253672169015 and parameters: {'max_bin': 526, 'learning_rate': 0.07088495921343135, 'max_depth': 8, 'min_child_weight': 2, 'subsample': 0.8708969974480867, 'colsample_bytree': 0.7780072327109965, 'colsample_bylevel': 0.7580091251836333, 'colsample_bynode': 0.6202034117403734, 'reg_alpha': 0.8851589453381403, 'reg_lambda': 0.7229452732873994, 'gamma': 0.9134859121833036, 'max_delta_step': 7, 'scale_pos_weight': 0.9810276847238313}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:04:49,501] Trial 41 finished with value: 0.04459419790742737 and parameters: {'max_bin': 525, 'learning_rate': 0.08771329229665635, 'max_depth': 8, 'min_child_weight': 2, 'subsample': 0.8774497385551184, 'colsample_bytree': 0.7823896699032926, 'colsample_bylevel': 0.9396654094830486, 'colsample_bynode': 0.5542513907937292, 'reg_alpha': 0.3366771047813898, 'reg_lambda': 0.7116531156622757, 'gamma': 0.9181908518487998, 'max_delta_step': 9, 'scale_pos_weight': 0.9966142278524157}. Best is trial 11 with value: 0.04452176771812045.
# [I 2025-11-26 16:04:51,409] Trial 42 finished with value: 0.044343839815182494 and parameters: {'max_bin': 529, 'learning_rate': 0.07127890539765201, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.8483380815195558, 'colsample_bytree': 0.7765643299427254, 'colsample_bylevel': 0.7501924993504284, 'colsample_bynode': 0.8584175075676193, 'reg_alpha': 0.3179472833647711, 'reg_lambda': 0.7458802750409238, 'gamma': 0.9098297249401842, 'max_delta_step': 9, 'scale_pos_weight': 0.9919761505588957}. Best is trial 42 with value: 0.044343839815182494.
# [I 2025-11-26 16:04:53,737] Trial 47 finished with value: 0.06559541801190379 and parameters: {'max_bin': 324, 'learning_rate': 0.07129671377371963, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.7670950669279196, 'colsample_bytree': 0.609079285340957, 'colsample_bylevel': 0.738002441002796, 'colsample_bynode': 0.3647930329973803, 'reg_alpha': 0.5512383043210178, 'reg_lambda': 0.4855998139750365, 'gamma': 0.6452935761687573, 'max_delta_step': 7, 'scale_pos_weight': 0.500362825600719}. Best is trial 42 with value: 0.044343839815182494.
# [I 2025-11-26 16:04:56,383] Trial 46 finished with value: 0.0468496705687169 and parameters: {'max_bin': 336, 'learning_rate': 0.0894306547967299, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.5509537339836867, 'colsample_bytree': 0.7721860405870533, 'colsample_bylevel': 0.9873458917461588, 'colsample_bynode': 0.37374431813497605, 'reg_alpha': 0.32594425004407224, 'reg_lambda': 0.4820174327015237, 'gamma': 0.6811067696218523, 'max_delta_step': 7, 'scale_pos_weight': 0.5193938086898099}. Best is trial 42 with value: 0.044343839815182494.
# [I 2025-11-26 16:05:13,700] Trial 44 finished with value: 0.04423656779952071 and parameters: {'max_bin': 525, 'learning_rate': 0.07091388637832352, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.896442677758628, 'colsample_bytree': 0.7715846738038884, 'colsample_bylevel': 0.9427418952347368, 'colsample_bynode': 0.848169595873733, 'reg_alpha': 0.8595783674803195, 'reg_lambda': 0.7247308490072654, 'gamma': 0.9118116437081798, 'max_delta_step': 7, 'scale_pos_weight': 0.9846978629480693}. Best is trial 44 with value: 0.04423656779952071.
# [I 2025-11-26 16:05:22,862] Trial 45 finished with value: 0.04414257404547036 and parameters: {'max_bin': 348, 'learning_rate': 0.07113810674300103, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.8535028041811524, 'colsample_bytree': 0.7646011335928142, 'colsample_bylevel': 0.9993387661355488, 'colsample_bynode': 0.8613255880549726, 'reg_alpha': 0.8918062283900434, 'reg_lambda': 0.7398463619449895, 'gamma': 0.6642796607242052, 'max_delta_step': 7, 'scale_pos_weight': 0.9873570921779334}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:05:24,303] Trial 49 finished with value: 0.047064569742461974 and parameters: {'max_bin': 327, 'learning_rate': 0.09134743861129291, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.7739373076365156, 'colsample_bytree': 0.6283076699506147, 'colsample_bylevel': 0.9859457015891875, 'colsample_bynode': 0.37953034887897463, 'reg_alpha': 0.3721321637688718, 'reg_lambda': 0.44927407709960654, 'gamma': 0.6716586919107208, 'max_delta_step': 9, 'scale_pos_weight': 0.5226784900842217}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:05:29,246] Trial 48 finished with value: 0.046569576239214074 and parameters: {'max_bin': 333, 'learning_rate': 0.09126786348346902, 'max_depth': 7, 'min_child_weight': 2, 'subsample': 0.7491237363962213, 'colsample_bytree': 0.782718198349702, 'colsample_bylevel': 0.7465940011547926, 'colsample_bynode': 0.3703493340379305, 'reg_alpha': 0.2250334521192143, 'reg_lambda': 0.4287314454454689, 'gamma': 0.6803446701709517, 'max_delta_step': 7, 'scale_pos_weight': 0.5194301207229876}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:06:05,430] Trial 52 finished with value: 0.04422447168267108 and parameters: {'max_bin': 396, 'learning_rate': 0.09345202564919824, 'max_depth': 7, 'min_child_weight': 2, 'subsample': 0.9214994982429009, 'colsample_bytree': 0.7271652698148443, 'colsample_bylevel': 0.8877592756828817, 'colsample_bynode': 0.8914083600942908, 'reg_alpha': 0.24285258287224915, 'reg_lambda': 0.8451637646113132, 'gamma': 0.8458708600492162, 'max_delta_step': 9, 'scale_pos_weight': 0.9259273101756486}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:06:12,021] Trial 50 finished with value: 0.04429809451742457 and parameters: {'max_bin': 308, 'learning_rate': 0.09258296327871761, 'max_depth': 7, 'min_child_weight': 2, 'subsample': 0.7984390484287844, 'colsample_bytree': 0.6251959891409555, 'colsample_bylevel': 0.9928299153207146, 'colsample_bynode': 0.9001274404486844, 'reg_alpha': 0.21416588803354192, 'reg_lambda': 0.855132843742815, 'gamma': 0.6881357383313143, 'max_delta_step': 9, 'scale_pos_weight': 0.926345579463163}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:06:15,354] Trial 51 finished with value: 0.04441271587802225 and parameters: {'max_bin': 391, 'learning_rate': 0.07202361458055581, 'max_depth': 7, 'min_child_weight': 2, 'subsample': 0.8237700376272861, 'colsample_bytree': 0.6124927540813904, 'colsample_bylevel': 0.8901480984309775, 'colsample_bynode': 0.886044018173084, 'reg_alpha': 0.2407191920169514, 'reg_lambda': 0.8391028210218845, 'gamma': 0.6795056602063807, 'max_delta_step': 9, 'scale_pos_weight': 0.924760833821881}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:06:22,932] Trial 57 finished with value: 0.04435825723207352 and parameters: {'max_bin': 276, 'learning_rate': 0.07648034280242738, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.9228369131745067, 'colsample_bytree': 0.7048709396396166, 'colsample_bylevel': 0.884053956437679, 'colsample_bynode': 0.9330424139012031, 'reg_alpha': 0.16567296210388832, 'reg_lambda': 0.8489280929628783, 'gamma': 0.5013809855612031, 'max_delta_step': 8, 'scale_pos_weight': 0.9237316485585683}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:06:27,398] Trial 53 finished with value: 0.045228254676706985 and parameters: {'max_bin': 543, 'learning_rate': 0.05165084404480809, 'max_depth': 7, 'min_child_weight': 2, 'subsample': 0.9226141646720435, 'colsample_bytree': 0.6382560901616096, 'colsample_bylevel': 0.8832411357434046, 'colsample_bynode': 0.8880873166139185, 'reg_alpha': 0.2129211797002969, 'reg_lambda': 0.8441248005779144, 'gamma': 0.8407919748529465, 'max_delta_step': 9, 'scale_pos_weight': 0.9178272602158394}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:06:29,581] Trial 54 finished with value: 0.04431184796676857 and parameters: {'max_bin': 543, 'learning_rate': 0.09136350718881556, 'max_depth': 8, 'min_child_weight': 2, 'subsample': 0.9146750275180252, 'colsample_bytree': 0.6436701628135526, 'colsample_bylevel': 0.8894981300189815, 'colsample_bynode': 0.9528304042556609, 'reg_alpha': 0.20464578537851483, 'reg_lambda': 0.850753480959601, 'gamma': 0.851291488485716, 'max_delta_step': 9, 'scale_pos_weight': 0.9183262841245973}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:06:40,352] Trial 55 finished with value: 0.04445149653587533 and parameters: {'max_bin': 301, 'learning_rate': 0.07616135047599673, 'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.8094999081145835, 'colsample_bytree': 0.6115594442057125, 'colsample_bylevel': 0.8878782734375182, 'colsample_bynode': 0.9239840163023214, 'reg_alpha': 0.20299006912649903, 'reg_lambda': 0.8475998113725558, 'gamma': 0.8499077984319101, 'max_delta_step': 9, 'scale_pos_weight': 0.9091331380646089}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:06:43,906] Trial 56 finished with value: 0.04423313888575509 and parameters: {'max_bin': 395, 'learning_rate': 0.07616583018304794, 'max_depth': 10, 'min_child_weight': 6, 'subsample': 0.9034121683835248, 'colsample_bytree': 0.7242871859861679, 'colsample_bylevel': 0.8851063559048622, 'colsample_bynode': 0.9153233265399218, 'reg_alpha': 0.2188441297219838, 'reg_lambda': 0.8506727179594338, 'gamma': 0.8514824131173558, 'max_delta_step': 8, 'scale_pos_weight': 0.925862239668611}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:07:04,506] Trial 61 finished with value: 0.045674702024731395 and parameters: {'max_bin': 289, 'learning_rate': 0.051159578674417325, 'max_depth': 3, 'min_child_weight': 6, 'subsample': 0.9089234469372273, 'colsample_bytree': 0.7155454174068725, 'colsample_bylevel': 0.997719728608167, 'colsample_bynode': 0.9472518720508761, 'reg_alpha': 0.16874105608499262, 'reg_lambda': 0.7643569398220912, 'gamma': 0.5117053900449318, 'max_delta_step': 9, 'scale_pos_weight': 0.92452114068825}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:07:18,970] Trial 62 finished with value: 0.04449741616965849 and parameters: {'max_bin': 291, 'learning_rate': 0.07638919250836007, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.8267519985802669, 'colsample_bytree': 0.7105951620160057, 'colsample_bylevel': 0.8700780628581678, 'colsample_bynode': 0.9365690995036484, 'reg_alpha': 0.19395079544507596, 'reg_lambda': 0.7578202606343569, 'gamma': 0.5275537006653779, 'max_delta_step': 10, 'scale_pos_weight': 0.8715606736592887}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:07:32,758] Trial 59 finished with value: 0.04424285394002283 and parameters: {'max_bin': 287, 'learning_rate': 0.0956465718456532, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.8169232892655471, 'colsample_bytree': 0.7186550613745224, 'colsample_bylevel': 0.8770760853280614, 'colsample_bynode': 0.9370089703235843, 'reg_alpha': 0.17289126354215256, 'reg_lambda': 0.7765717127115627, 'gamma': 0.8551793286539875, 'max_delta_step': 10, 'scale_pos_weight': 0.906006288051365}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:07:32,810] Trial 58 finished with value: 0.04422818467320279 and parameters: {'max_bin': 386, 'learning_rate': 0.07642201743585768, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.9203507690734885, 'colsample_bytree': 0.7245962430239677, 'colsample_bylevel': 0.877103711440844, 'colsample_bynode': 0.9259234529961534, 'reg_alpha': 0.18573894211431924, 'reg_lambda': 0.7726849824295503, 'gamma': 0.8392371799155678, 'max_delta_step': 8, 'scale_pos_weight': 0.9317296481677457}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:07:41,555] Trial 63 finished with value: 0.044580305003631235 and parameters: {'max_bin': 302, 'learning_rate': 0.09507894671535636, 'max_depth': 10, 'min_child_weight': 6, 'subsample': 0.8122909429059364, 'colsample_bytree': 0.5660126278548527, 'colsample_bylevel': 0.9929394040579135, 'colsample_bynode': 0.9816689824559507, 'reg_alpha': 0.16785668358110084, 'reg_lambda': 0.7755419357069308, 'gamma': 0.7283658936560498, 'max_delta_step': 10, 'scale_pos_weight': 0.869059955400242}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:07:49,400] Trial 65 finished with value: 0.04449472325348526 and parameters: {'max_bin': 282, 'learning_rate': 0.09451952761974997, 'max_depth': 10, 'min_child_weight': 6, 'subsample': 0.933803763395707, 'colsample_bytree': 0.5673926754562912, 'colsample_bylevel': 0.9904436111809162, 'colsample_bynode': 0.9960076679266343, 'reg_alpha': 0.7282029096176201, 'reg_lambda': 0.939449259088606, 'gamma': 0.7317297810430563, 'max_delta_step': 10, 'scale_pos_weight': 0.8694400357357986}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:07:53,398] Trial 64 finished with value: 0.04443046340247475 and parameters: {'max_bin': 356, 'learning_rate': 0.09452690087560776, 'max_depth': 8, 'min_child_weight': 7, 'subsample': 0.8244628819814247, 'colsample_bytree': 0.5425274935839443, 'colsample_bylevel': 0.998240170477722, 'colsample_bynode': 0.9830244400538081, 'reg_alpha': 0.7595082391505095, 'reg_lambda': 0.7638912516991241, 'gamma': 0.5205868181785054, 'max_delta_step': 10, 'scale_pos_weight': 0.8512848313617848}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:08:13,319] Trial 66 finished with value: 0.04457357515170289 and parameters: {'max_bin': 403, 'learning_rate': 0.09479178025511326, 'max_depth': 10, 'min_child_weight': 7, 'subsample': 0.9525041056662576, 'colsample_bytree': 0.572256896640154, 'colsample_bylevel': 0.865688073002982, 'colsample_bynode': 0.991194171084554, 'reg_alpha': 0.7320927127336043, 'reg_lambda': 0.9364496266971164, 'gamma': 0.7291899422104804, 'max_delta_step': 10, 'scale_pos_weight': 0.8651028611761385}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:08:15,618] Trial 60 finished with value: 0.04449940392750497 and parameters: {'max_bin': 298, 'learning_rate': 0.050707631805374034, 'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.8216554180821097, 'colsample_bytree': 0.7212470772355054, 'colsample_bylevel': 0.8829493512972607, 'colsample_bynode': 0.9206231188720762, 'reg_alpha': 0.16996061950833807, 'reg_lambda': 0.7702468573378211, 'gamma': 0.48774993589159216, 'max_delta_step': 9, 'scale_pos_weight': 0.9175115613416454}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16
 'max_depth': 8, 'min_child_weight': 9, 'subsample': 0.9970895733285076, 'colsample_bytree': 0.8052167789176381, 'colsample_bylevel': 0.9606237698359896, 'colsample_bynode': 0.862141224796962, 'reg_alpha': 0.24383435721450147, 'reg_lambda': 0.7320118539201653, 'gamma': 0.5744729439138414, 'max_delta_step': 6, 'scale_pos_weight': 0.8878543618285103}. Best is trial 45 with value: 0.04414257404547036.
# [I 2025-11-26 16:11:56,280] Trial 86 finished with value: 0.04409450803271109 and parameters: {'max_bin': 411, 'learning_rate': 0.06892565255935962, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.9930700965944752, 'colsample_bytree': 0.8068876020175303, 'colsample_bylevel': 0.95378014646545, 'colsample_bynode': 0.8565683668854942, 'reg_alpha': 0.2488241885190039, 'reg_lambda': 0.8915931097756422, 'gamma': 0.6226052054482493, 'max_delta_step': 6, 'scale_pos_weight': 0.8930020004705437}. Best is trial 86 with value: 0.04409450803271109.
# [I 2025-11-26 16:12:08,664] Trial 90 finished with value: 0.044097796073075415 and parameters: {'max_bin': 414, 'learning_rate': 0.07881392744089999, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9915219001820079, 'colsample_bytree': 0.8086707218607159, 'colsample_bylevel': 0.935892312497604, 'colsample_bynode': 0.8721370664734007, 'reg_alpha': 0.2447337714912769, 'reg_lambda': 0.7346124497494433, 'gamma': 0.6289070874998488, 'max_delta_step': 6, 'scale_pos_weight': 0.8935046667502197}. Best is trial 86 with value: 0.04409450803271109.
# [I 2025-11-26 16:12:20,310] Trial 89 finished with value: 0.04408243574448457 and parameters: {'max_bin': 402, 'learning_rate': 0.07410866549878589, 'max_depth': 8, 'min_child_weight': 9, 'subsample': 0.9767746235386727, 'colsample_bytree': 0.807724211683728, 'colsample_bylevel': 0.783633761974985, 'colsample_bynode': 0.8623346315026442, 'reg_alpha': 0.25183429874849833, 'reg_lambda': 0.8638071231268627, 'gamma': 0.5978189275365163, 'max_delta_step': 6, 'scale_pos_weight': 0.8888947782254139}. Best is trial 89 with value: 0.04408243574448457.
# [I 2025-11-26 16:12:21,889] Trial 91 finished with value: 0.04414705840573436 and parameters: {'max_bin': 412, 'learning_rate': 0.07889027369770665, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.7899938023353826, 'colsample_bytree': 0.8033192444955025, 'colsample_bylevel': 0.7869754465062281, 'colsample_bynode': 0.8572235625488366, 'reg_alpha': 0.25288761999141474, 'reg_lambda': 0.7332394388978375, 'gamma': 0.5975589082106427, 'max_delta_step': 9, 'scale_pos_weight': 0.8947709609619664}. Best is trial 89 with value: 0.04408243574448457.
# [I 2025-11-26 16:12:37,716] Trial 94 finished with value: 0.045960333383011184 and parameters: {'max_bin': 452, 'learning_rate': 0.05856427101900625, 'max_depth': 9, 'min_child_weight': 3, 'subsample': 0.8559201661635893, 'colsample_bytree': 0.8089930285678211, 'colsample_bylevel': 0.5131559687321807, 'colsample_bynode': 0.8688874391503199, 'reg_alpha': 0.9298093843945993, 'reg_lambda': 0.7336379820082645, 'gamma': 0.5674327986573517, 'max_delta_step': 7, 'scale_pos_weight': 0.8502993372353083}. Best is trial 89 with value: 0.04408243574448457.
# [I 2025-11-26 16:12:39,186] Trial 92 finished with value: 0.04411487414834982 and parameters: {'max_bin': 315, 'learning_rate': 0.07416883542880921, 'max_depth': 7, 'min_child_weight': 10, 'subsample': 0.8523796086260984, 'colsample_bytree': 0.7997464476167746, 'colsample_bylevel': 0.9414593142196568, 'colsample_bynode': 0.9090282164161317, 'reg_alpha': 0.9160731430798529, 'reg_lambda': 0.7142703359823355, 'gamma': 0.6150899800836493, 'max_delta_step': 9, 'scale_pos_weight': 0.8505391513142522}. Best is trial 89 with value: 0.04408243574448457.
# [I 2025-11-26 16:12:48,092] Trial 93 finished with value: 0.04408324066585377 and parameters: {'max_bin': 407, 'learning_rate': 0.08067324844068668, 'max_depth': 9, 'min_child_weight': 10, 'subsample': 0.9753278221669499, 'colsample_bytree': 0.8132226908720868, 'colsample_bylevel': 0.9364666330708203, 'colsample_bynode': 0.8682861168890101, 'reg_alpha': 0.8915485275943945, 'reg_lambda': 0.729384175699414, 'gamma': 0.5496121604156486, 'max_delta_step': 7, 'scale_pos_weight': 0.8430900625778026}. Best is trial 89 with value: 0.04408243574448457.
# [I 2025-11-26 16:13:06,885] Trial 95 finished with value: 0.04437282902733054 and parameters: {'max_bin': 416, 'learning_rate': 0.05690533914839008, 'max_depth': 9, 'min_child_weight': 10, 'subsample': 0.9778734555909839, 'colsample_bytree': 0.8194924390493411, 'colsample_bylevel': 0.9391273158986331, 'colsample_bynode': 0.690485427908698, 'reg_alpha': 0.9133191965465896, 'reg_lambda': 0.735874761162487, 'gamma': 0.5606181486526167, 'max_delta_step': 7, 'scale_pos_weight': 0.38814969288775775}. Best is trial 89 with value: 0.04408243574448457.
# [I 2025-11-26 16:13:13,638] Trial 99 finished with value: 0.04566723916555689 and parameters: {'max_bin': 418, 'learning_rate': 0.05833781704208546, 'max_depth': 7, 'min_child_weight': 10, 'subsample': 0.9717223195306315, 'colsample_bytree': 0.8215444974782504, 'colsample_bylevel': 0.5996864792699443, 'colsample_bynode': 0.6859786409028116, 'reg_alpha': 0.37139360473135546, 'reg_lambda': 0.6929470095699454, 'gamma': 0.5770656695871551, 'max_delta_step': 5, 'scale_pos_weight': 0.7194060383935283}. Best is trial 89 with value: 0.04408243574448457.
# [I 2025-11-26 16:13:19,519] Trial 97 finished with value: 0.04418737172648742 and parameters: {'max_bin': 420, 'learning_rate': 0.05415208968977732, 'max_depth': 9, 'min_child_weight': 10, 'subsample': 0.9751537209506306, 'colsample_bytree': 0.8046640896904746, 'colsample_bylevel': 0.9344953014625128, 'colsample_bynode': 0.8733062999722618, 'reg_alpha': 0.3671185625313201, 'reg_lambda': 0.5964261625147748, 'gamma': 0.5816959474925476, 'max_delta_step': 5, 'scale_pos_weight': 0.8520181269307345}. Best is trial 89 with value: 0.04408243574448457.
# [I 2025-11-26 16:13:22,719] Trial 96 finished with value: 0.04421609943796957 and parameters: {'max_bin': 417, 'learning_rate': 0.054775001505786715, 'max_depth': 9, 'min_child_weight': 10, 'subsample': 0.9738074576726479, 'colsample_bytree': 0.8134795023300371, 'colsample_bylevel': 0.7852981324032735, 'colsample_bynode': 0.8677407665632108, 'reg_alpha': 0.23953232521116954, 'reg_lambda': 0.7455499612805635, 'gamma': 0.5806658742014386, 'max_delta_step': 7, 'scale_pos_weight': 0.8450776028515653}. Best is trial 89 with value: 0.04408243574448457.
# [I 2025-11-26 16:13:23,851] Trial 98 finished with value: 0.04523662301020873 and parameters: {'max_bin': 418, 'learning_rate': 0.03952167215456039, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.971700898751146, 'colsample_bytree': 0.8116751928022408, 'colsample_bylevel': 0.7775059750364145, 'colsample_bynode': 0.8738217151624146, 'reg_alpha': 0.23964924784053254, 'reg_lambda': 0.694961892114465, 'gamma': 0.5704590402739471, 'max_delta_step': 5, 'scale_pos_weight': 0.843550399285931}. Best is trial 89 with value: 0.04408243574448457.

# %% [markdown]
# stratified k-fold

# %%
#use 7 fold
FOLD = 7

# %%
#stratification bins
#In practice, many data scientists use standard K-fold for regression first, 
# and only implement binned stratification if the results show high variance across folds 
# or if the target distribution is highly imbalanced.
#q=10 best practice, and must be q > k.(q  = 10 must be larger than k = 7 fold)
#this q will also have positive relationship with data,if data is large q also should be increased

y_bins = pd.qcut(y_train,q=10,labels=False,duplicates='drop')

# %%
skf = StratifiedKFold(n_splits=FOLD,shuffle=True,random_state=42)
fold_splits = list(skf.split(X_train,y_bins))

# %%
fold_splits
# Out:
# [(array([     0,      1,      2, ..., 517749, 517750, 517751]),
#   array([     8,     17,     43, ..., 517728, 517752, 517753])),
#  (array([     1,      2,      4, ..., 517751, 517752, 517753]),
#   array([     0,      3,      7, ..., 517726, 517735, 517737])),
#  (array([     0,      1,      3, ..., 517751, 517752, 517753]),
#   array([     2,     32,     35, ..., 517732, 517745, 517750])),
#  (array([     0,      1,      2, ..., 517751, 517752, 517753]),
#   array([     9,     16,     21, ..., 517743, 517744, 517749])),
#  (array([     0,      1,      2, ..., 517751, 517752, 517753]),
#   array([     4,     12,     13, ..., 517741, 517742, 517746])),
#  (array([     0,      1,      2, ..., 517751, 517752, 517753]),
#   array([     5,     10,     11, ..., 517731, 517733, 517747])),
#  (array([     0,      2,      3, ..., 517750, 517752, 517753]),
#   array([     1,      6,     23, ..., 517740, 517748, 517751]))]

# %%
oof_prediction = np.zeros(len(X_train))
test_prediction = np.zeros(len(X_test))

fold_scores = []
# feature_importance_dict = {}

# %%
for fold,(train_idx,val_idx) in enumerate(fold_splits,1):
    print(f'Fold {fold}/{FOLD}')

    X_tr,X_val = X_train.iloc[train_idx],X_train.iloc[val_idx]
    y_tr,y_val = y_train.iloc[train_idx],y_train.iloc[val_idx]

    dtrain = xgb.DMatrix(X_tr,label=y_tr)
    dval = xgb.DMatrix(X_val,label=y_val)
    dtest = xgb.DMatrix(X_test)

    model = xgb.train(
        params = study.best_params,
        dtrain = dtrain,
        num_boost_round = 10000,
        evals = [(dval,'valid')],
        early_stopping_rounds = 200,
        verbose_eval = False
    )

    oof_prediction[val_idx] = model.predict(dval)
    test_prediction += model.predict(dtest)

    fold_rmse = np.sqrt(np.mean((oof_prediction[val_idx] - y_val)**2))
    fold_scores.append(fold_rmse)
    print(f'FOLD {fold} RMSE:{fold_rmse:.6f}')

test_prediction/=FOLD
# Out:
# Fold 1/7
# FOLD 1 RMSE:0.056769
# Fold 2/7
# FOLD 2 RMSE:0.056292
# Fold 3/7
# FOLD 3 RMSE:0.056503
# Fold 4/7
# FOLD 4 RMSE:0.056268
# Fold 5/7
# FOLD 5 RMSE:0.056907
# Fold 6/7
# FOLD 6 RMSE:0.056689
# Fold 7/7
# FOLD 7 RMSE:0.056670

# %%
print(f'Average RMSE:{np.mean(fold_scores):.4f}')
# Out:
# Average RMSE:0.0566

# %%
print(test_prediction)
# Out:
# [0.2942352  0.13062514 0.19341974 ... 0.25150612 0.13364523 0.48470294]
