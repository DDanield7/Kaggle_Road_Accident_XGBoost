# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt 
import xgboost as xgb #use xgb as algorthm model
from xgboost import XGBRegressor #use xgb regressor because we want to predict continuous numerical value
from sklearn.preprocessing import LabelEncoder #encode all categorical and boolean feature
import optuna # hyperparameter tuning using optuna
from sklearn.model_selection import cross_val_score #to evaluate model
from sklearn.model_selection import StratifiedKFold #to perform k-fold

# %%
data_train = pd.read_csv('./train.csv')
data_test = pd.read_csv('./test.csv')

# %%
#divide dataset into 4
y_train = data_train['accident_risk'] #target train
train_ids = data_train['id'] #target train id
test_ids = data_test['id'] #target test id
train = data_train.drop(['accident_risk','id'],axis=1) #train feature 
test = data_test.drop(['id'],axis=1) # test feature

# %%
X_train = train.copy()
X_test = test.copy()

# %%
#feature encoding

#first select categorical,object and boolean column
cat_col = X_train.select_dtypes(['object','bool']).columns

# %%
#label encode

#in test data we use only transform, to prevent inconsistency, like example: in training blue encoded as 1,
#so when in test dataset the blue also encoded as 1 not 0 or other number.
for col in cat_col:
    le = LabelEncoder()
    X_train[col] = le.fit_transform(X_train[col].astype(str))
    X_test[col] = le.transform(X_test[col].astype(str))

# %%
def objective(trial):

    #optuna will search the best output given a specified range of numbers
    xgb_params = {
        'objective': 'reg:squarederror',
        'max_bin': trial.suggest_int('max_bin',100,600),
        'learning_rate': trial.suggest_float('learning_rate',0.01,0.1),
        'max_depth': trial.suggest_int('max_depth',1,10),
        'min_child_weight': trial.suggest_int('min_child_weight',1,10),
        'subsample': trial.suggest_float('subsample',0.1,1),
        'colsample_bytree': trial.suggest_float('colsample_bytree',0.1,1),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel',0.1,1),
        'colsample_bynode': trial.suggest_float('colsample_bynode',0.1,1),
        'reg_alpha': trial.suggest_float('reg_alpha',0.1,1),
        'reg_lambda': trial.suggest_float('reg_lambda',0.1,1),
        'gamma': trial.suggest_float('gamma',0.1,1),
        'max_delta_step': trial.suggest_int('max_delta_step',0,10),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight',0.1,1)
    }

    model = XGBRegressor(**xgb_params,tree_method='hist',device='cuda') #configure xgbregressor model

    #evaluate model
    score = cross_val_score(model,X_train,y_train,cv=7,scoring='neg_mean_absolute_error')#cross_val_score do .fit() internally
    mae = -score.mean()
    return mae

# %%
#configure optuna
study = optuna.create_study(study_name='xgboost_optuna_roadaccident_comp',direction='minimize')
study.optimize(objective,n_trials=100,show_progress_bar=True,n_jobs=-1) #njobs -1 to run on all cores to speed up process
# Out:
# [I 2025-11-21 14:32:52,005] A new study created in memory with name: xgboost_optuna_roadaccident_comp
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-11-21 14:33:27,063] Trial 0 finished with value: 0.10639525848728064 and parameters: {'max_bin': 466, 'learning_rate': 0.023411025863006276, 'max_depth': 2, 'min_child_weight': 8, 'subsample': 0.6069017797712604, 'colsample_bytree': 0.19388425058172662, 'colsample_bylevel': 0.7585922744715062, 'colsample_bynode': 0.9696221997352242, 'reg_alpha': 0.37770442499178825, 'reg_lambda': 0.9829742252144665, 'gamma': 0.2241415316338511, 'max_delta_step': 6, 'scale_pos_weight': 0.9236709894784747}. Best is trial 0 with value: 0.10639525848728064.
# [I 2025-11-21 14:33:30,804] Trial 2 finished with value: 0.11255718141169449 and parameters: {'max_bin': 522, 'learning_rate': 0.01731713318054443, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 0.46691693786754473, 'colsample_bytree': 0.3220288575926916, 'colsample_bylevel': 0.9817872915574828, 'colsample_bynode': 0.7896465439068513, 'reg_alpha': 0.2896555753553024, 'reg_lambda': 0.11759468124540845, 'gamma': 0.19175604706817434, 'max_delta_step': 0, 'scale_pos_weight': 0.34110679080551765}. Best is trial 0 with value: 0.10639525848728064.
# [I 2025-11-21 14:33:31,288] Trial 3 finished with value: 0.07733847375180793 and parameters: {'max_bin': 592, 'learning_rate': 0.07371110673546326, 'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.10525586137403886, 'colsample_bytree': 0.3264223295705109, 'colsample_bylevel': 0.8682616651501945, 'colsample_bynode': 0.4497651882553535, 'reg_alpha': 0.13140488297424394, 'reg_lambda': 0.8529365692349834, 'gamma': 0.934572920840511, 'max_delta_step': 9, 'scale_pos_weight': 0.3546756922464358}. Best is trial 3 with value: 0.07733847375180793.
# [I 2025-11-21 14:33:32,178] Trial 1 finished with value: 0.08123687304005656 and parameters: {'max_bin': 600, 'learning_rate': 0.05811719441028034, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.12263360037912441, 'colsample_bytree': 0.6288758017214677, 'colsample_bylevel': 0.3900100955754857, 'colsample_bynode': 0.28970894402730807, 'reg_alpha': 0.9669387868863243, 'reg_lambda': 0.5658134709959868, 'gamma': 0.42134621928155824, 'max_delta_step': 10, 'scale_pos_weight': 0.5023905571863738}. Best is trial 3 with value: 0.07733847375180793.
# [I 2025-11-21 14:33:32,595] Trial 4 finished with value: 0.10168009977685714 and parameters: {'max_bin': 120, 'learning_rate': 0.031366462289919655, 'max_depth': 5, 'min_child_weight': 10, 'subsample': 0.17703177545639395, 'colsample_bytree': 0.25374151095710984, 'colsample_bylevel': 0.18692621069485787, 'colsample_bynode': 0.6801295947830125, 'reg_alpha': 0.34488762768563797, 'reg_lambda': 0.764905059043531, 'gamma': 0.9173719293773865, 'max_delta_step': 8, 'scale_pos_weight': 0.638590818260831}. Best is trial 3 with value: 0.07733847375180793.
# [I 2025-11-21 14:33:35,638] Trial 7 finished with value: 0.06211310525169266 and parameters: {'max_bin': 158, 'learning_rate': 0.0717127692491609, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.4559910679779755, 'colsample_bytree': 0.8989636318938612, 'colsample_bylevel': 0.2639770164899554, 'colsample_bynode': 0.16969147739702145, 'reg_alpha': 0.6822481981596368, 'reg_lambda': 0.7656828983723973, 'gamma': 0.8152427945068234, 'max_delta_step': 4, 'scale_pos_weight': 0.8575389686822599}. Best is trial 7 with value: 0.06211310525169266.
# [I 2025-11-21 14:33:40,103] Trial 5 finished with value: 0.047699218151262365 and parameters: {'max_bin': 337, 'learning_rate': 0.06134666584436505, 'max_depth': 3, 'min_child_weight': 10, 'subsample': 0.17624823833989833, 'colsample_bytree': 0.7572130936449768, 'colsample_bylevel': 0.6911813228437447, 'colsample_bynode': 0.539932335570079, 'reg_alpha': 0.8484473066791696, 'reg_lambda': 0.9710289718238719, 'gamma': 0.29719419342395376, 'max_delta_step': 5, 'scale_pos_weight': 0.7351183279338052}. Best is trial 5 with value: 0.047699218151262365.
# [I 2025-11-21 14:33:56,534] Trial 6 finished with value: 0.10906893350085096 and parameters: {'max_bin': 577, 'learning_rate': 0.01374229532491284, 'max_depth': 9, 'min_child_weight': 8, 'subsample': 0.4007309822502596, 'colsample_bytree': 0.9188624889893681, 'colsample_bylevel': 0.13395544831117132, 'colsample_bynode': 0.14979316023496547, 'reg_alpha': 0.8629149963125017, 'reg_lambda': 0.636764023140039, 'gamma': 0.3524250548231389, 'max_delta_step': 8, 'scale_pos_weight': 0.8925104227881064}. Best is trial 5 with value: 0.047699218151262365.
# [I 2025-11-21 14:34:06,208] Trial 8 finished with value: 0.08635331489031468 and parameters: {'max_bin': 227, 'learning_rate': 0.04018595923082168, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.507590901821905, 'colsample_bytree': 0.27189685886587034, 'colsample_bylevel': 0.7774306098283801, 'colsample_bynode': 0.7755569601328453, 'reg_alpha': 0.9371248440269844, 'reg_lambda': 0.23244900862370466, 'gamma': 0.9548931233576763, 'max_delta_step': 3, 'scale_pos_weight': 0.5902712169734101}. Best is trial 5 with value: 0.047699218151262365.
# [I 2025-11-21 14:34:08,072] Trial 12 finished with value: 0.1075574277134609 and parameters: {'max_bin': 286, 'learning_rate': 0.027928897589238035, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.6242314811768456, 'colsample_bytree': 0.27115810987148714, 'colsample_bylevel': 0.5960427224841365, 'colsample_bynode': 0.7629438306851962, 'reg_alpha': 0.6890671613222572, 'reg_lambda': 0.46975175005184133, 'gamma': 0.9455838784446173, 'max_delta_step': 5, 'scale_pos_weight': 0.19620888693985433}. Best is trial 5 with value: 0.047699218151262365.
# [I 2025-11-21 14:34:12,668] Trial 13 finished with value: 0.06255871846712545 and parameters: {'max_bin': 308, 'learning_rate': 0.09882910305974703, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.24051267386089376, 'colsample_bytree': 0.33830757664186023, 'colsample_bylevel': 0.9157895046223786, 'colsample_bynode': 0.5662022002341232, 'reg_alpha': 0.8824555708792469, 'reg_lambda': 0.2986158319029749, 'gamma': 0.2764599171477219, 'max_delta_step': 7, 'scale_pos_weight': 0.941645684946203}. Best is trial 5 with value: 0.047699218151262365.
# [I 2025-11-21 14:34:17,806] Trial 10 finished with value: 0.10249785744667239 and parameters: {'max_bin': 239, 'learning_rate': 0.022551394755340008, 'max_depth': 9, 'min_child_weight': 1, 'subsample': 0.2742654021747118, 'colsample_bytree': 0.49968781807449925, 'colsample_bylevel': 0.4237606569775699, 'colsample_bynode': 0.4489955488495281, 'reg_alpha': 0.1611698588424631, 'reg_lambda': 0.8270353284036869, 'gamma': 0.6026751190808814, 'max_delta_step': 10, 'scale_pos_weight': 0.6153086264862371}. Best is trial 5 with value: 0.047699218151262365.
# [I 2025-11-21 14:34:32,759] Trial 17 finished with value: 0.07699503621819358 and parameters: {'max_bin': 396, 'learning_rate': 0.09566795115342425, 'max_depth': 1, 'min_child_weight': 10, 'subsample': 0.926974398556673, 'colsample_bytree': 0.7026745427623751, 'colsample_bylevel': 0.5350007821998635, 'colsample_bynode': 0.47848515604947545, 'reg_alpha': 0.7184230111243834, 'reg_lambda': 0.3847571195792465, 'gamma': 0.6332957844172833, 'max_delta_step': 1, 'scale_pos_weight': 0.7475361252570563}. Best is trial 5 with value: 0.047699218151262365.
# [I 2025-11-21 14:34:37,759] Trial 18 finished with value: 0.08436082141710795 and parameters: {'max_bin': 412, 'learning_rate': 0.07229087618881753, 'max_depth': 1, 'min_child_weight': 5, 'subsample': 0.8871793163745234, 'colsample_bytree': 0.8947801373530375, 'colsample_bylevel': 0.4240304048348037, 'colsample_bynode': 0.3387010202041889, 'reg_alpha': 0.6541107756362656, 'reg_lambda': 0.9762207594003288, 'gamma': 0.6540652946944578, 'max_delta_step': 3, 'scale_pos_weight': 0.7322096947487922}. Best is trial 5 with value: 0.047699218151262365.
# [I 2025-11-21 14:34:40,545] Trial 15 finished with value: 0.05974240697074278 and parameters: {'max_bin': 269, 'learning_rate': 0.08823827549397747, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.9458425418598757, 'colsample_bytree': 0.39026995694175504, 'colsample_bylevel': 0.26380231782960173, 'colsample_bynode': 0.8807168626572353, 'reg_alpha': 0.49879450675860837, 'reg_lambda': 0.9761559901963324, 'gamma': 0.6341237265312256, 'max_delta_step': 1, 'scale_pos_weight': 0.6916303498383567}. Best is trial 5 with value: 0.047699218151262365.
# [I 2025-11-21 14:34:40,890] Trial 11 finished with value: 0.045811015511315674 and parameters: {'max_bin': 187, 'learning_rate': 0.0563683599016064, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8755850625830913, 'colsample_bytree': 0.9626547190335503, 'colsample_bylevel': 0.6205207334794436, 'colsample_bynode': 0.5944440067072159, 'reg_alpha': 0.3019563410099795, 'reg_lambda': 0.37585460730433196, 'gamma': 0.6531624073871194, 'max_delta_step': 5, 'scale_pos_weight': 0.9098943111701883}. Best is trial 11 with value: 0.045811015511315674.
# [I 2025-11-21 14:34:43,166] Trial 19 finished with value: 0.08692443102744077 and parameters: {'max_bin': 400, 'learning_rate': 0.0737132353031722, 'max_depth': 1, 'min_child_weight': 5, 'subsample': 0.9159499830391715, 'colsample_bytree': 0.9128377683391369, 'colsample_bylevel': 0.5722454922578611, 'colsample_bynode': 0.13768510965650999, 'reg_alpha': 0.6370544959060367, 'reg_lambda': 0.9804449451838317, 'gamma': 0.6708941974828392, 'max_delta_step': 3, 'scale_pos_weight': 0.7685662297631918}. Best is trial 11 with value: 0.045811015511315674.
# [I 2025-11-21 14:34:46,131] Trial 9 finished with value: 0.08692426339584311 and parameters: {'max_bin': 298, 'learning_rate': 0.010002708463955644, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.6179328451590558, 'colsample_bytree': 0.782567860760974, 'colsample_bylevel': 0.9271116230871447, 'colsample_bynode': 0.49759975719527627, 'reg_alpha': 0.5168419392627902, 'reg_lambda': 0.13154781687901856, 'gamma': 0.2244165992143181, 'max_delta_step': 4, 'scale_pos_weight': 0.8312174059681333}. Best is trial 11 with value: 0.045811015511315674.
# [I 2025-11-21 14:34:52,671] Trial 16 finished with value: 0.11120474410403133 and parameters: {'max_bin': 101, 'learning_rate': 0.01440410134474757, 'max_depth': 7, 'min_child_weight': 10, 'subsample': 0.366283193857203, 'colsample_bytree': 0.4117280624921066, 'colsample_bylevel': 0.8572962751162984, 'colsample_bynode': 0.34125353781120005, 'reg_alpha': 0.3087879599964243, 'reg_lambda': 0.7671844009005754, 'gamma': 0.28263433734579346, 'max_delta_step': 5, 'scale_pos_weight': 0.11869207646456324}. Best is trial 11 with value: 0.045811015511315674.
# [I 2025-11-21 14:35:09,405] Trial 14 finished with value: 0.05065888050388182 and parameters: {'max_bin': 540, 'learning_rate': 0.04718920471880764, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.8039220769888744, 'colsample_bytree': 0.49397350050494715, 'colsample_bylevel': 0.8427963896158914, 'colsample_bynode': 0.9468403038098224, 'reg_alpha': 0.8595239080161577, 'reg_lambda': 0.313471974727758, 'gamma': 0.5088889483864284, 'max_delta_step': 5, 'scale_pos_weight': 0.14410514251735929}. Best is trial 11 with value: 0.045811015511315674.
# [I 2025-11-21 14:35:10,710] Trial 20 finished with value: 0.0710211005018824 and parameters: {'max_bin': 129, 'learning_rate': 0.07437098427950989, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.7316535425793589, 'colsample_bytree': 0.975979300183187, 'colsample_bylevel': 0.2829056284974856, 'colsample_bynode': 0.15370566909446018, 'reg_alpha': 0.5912953243178594, 'reg_lambda': 0.9760983576201864, 'gamma': 0.6955066082510027, 'max_delta_step': 4, 'scale_pos_weight': 0.8153997450420861}. Best is trial 11 with value: 0.045811015511315674.
# [I 2025-11-21 14:35:15,753] Trial 21 finished with value: 0.0669765740383135 and parameters: {'max_bin': 105, 'learning_rate': 0.06417028365784012, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.7204616014057127, 'colsample_bytree': 0.7827684332881852, 'colsample_bylevel': 0.2625188958141122, 'colsample_bynode': 0.12420301253682958, 'reg_alpha': 0.5778914201104342, 'reg_lambda': 0.6777524914844499, 'gamma': 0.7645777834726774, 'max_delta_step': 3, 'scale_pos_weight': 0.8106551343446475}. Best is trial 11 with value: 0.045811015511315674.
# [I 2025-11-21 14:35:39,892] Trial 22 finished with value: 0.04710854647617278 and parameters: {'max_bin': 362, 'learning_rate': 0.08757730850582125, 'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.8173922608591027, 'colsample_bytree': 0.4862062269800031, 'colsample_bylevel': 0.6116417375181232, 'colsample_bynode': 0.9773953547393779, 'reg_alpha': 0.4841167195132854, 'reg_lambda': 0.9219956013203164, 'gamma': 0.4631587849944564, 'max_delta_step': 2, 'scale_pos_weight': 0.7690005033681246}. Best is trial 11 with value: 0.045811015511315674.
# [I 2025-11-21 14:35:54,789] Trial 29 finished with value: 0.0801366385567905 and parameters: {'max_bin': 196, 'learning_rate': 0.04527847695437926, 'max_depth': 10, 'min_child_weight': 3, 'subsample': 0.7888332032897064, 'colsample_bytree': 0.5129949010094277, 'colsample_bylevel': 0.6577368681086708, 'colsample_bynode': 0.6088045017010095, 'reg_alpha': 0.802358047104863, 'reg_lambda': 0.43043727619846966, 'gamma': 0.49167595309600787, 'max_delta_step': 6, 'scale_pos_weight': 0.9987360687792572}. Best is trial 11 with value: 0.045811015511315674.
# [I 2025-11-21 14:36:01,164] Trial 23 finished with value: 0.04682688820927431 and parameters: {'max_bin': 187, 'learning_rate': 0.0493294588307511, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.765625047295787, 'colsample_bytree': 0.7716622016692228, 'colsample_bylevel': 0.6435465885481173, 'colsample_bynode': 0.6052368605468568, 'reg_alpha': 0.5209337097614235, 'reg_lambda': 0.61090565200911, 'gamma': 0.46881173237099844, 'max_delta_step': 5, 'scale_pos_weight': 0.8152979292739537}. Best is trial 11 with value: 0.045811015511315674.
# [I 2025-11-21 14:36:13,497] Trial 24 finished with value: 0.04642138866614003 and parameters: {'max_bin': 180, 'learning_rate': 0.05080158694168516, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.7593257128522872, 'colsample_bytree': 0.7708958130038293, 'colsample_bylevel': 0.6861531051248035, 'colsample_bynode': 0.602358543041764, 'reg_alpha': 0.49216881916499067, 'reg_lambda': 0.45368963717933847, 'gamma': 0.46591375846273303, 'max_delta_step': 5, 'scale_pos_weight': 0.8117983348069062}. Best is trial 11 with value: 0.045811015511315674.
# [I 2025-11-21 14:36:15,943] Trial 27 finished with value: 0.04611384351939031 and parameters: {'max_bin': 203, 'learning_rate': 0.05873876379271333, 'max_depth': 6, 'min_child_weight': 6, 'subsample': 0.7477079914835151, 'colsample_bytree': 0.785037019036891, 'colsample_bylevel': 0.6835736561297848, 'colsample_bynode': 0.6399425415847232, 'reg_alpha': 0.43708371429378007, 'reg_lambda': 0.6341673035887617, 'gamma': 0.7603480456841272, 'max_delta_step': 7, 'scale_pos_weight': 0.9945285000583006}. Best is trial 11 with value: 0.045811015511315674.
# [I 2025-11-21 14:36:28,252] Trial 31 finished with value: 0.04718157731933091 and parameters: {'max_bin': 364, 'learning_rate': 0.08572369491278944, 'max_depth': 3, 'min_child_weight': 9, 'subsample': 0.852048796149158, 'colsample_bytree': 0.6131834525651376, 'colsample_bylevel': 0.6935632220636663, 'colsample_bynode': 0.6719681551271721, 'reg_alpha': 0.42960481842794346, 'reg_lambda': 0.8895277608346379, 'gamma': 0.11406582190912998, 'max_delta_step': 2, 'scale_pos_weight': 0.5363106995792319}. Best is trial 11 with value: 0.045811015511315674.
# [I 2025-11-21 14:36:29,030] Trial 26 finished with value: 0.04473684929875273 and parameters: {'max_bin': 173, 'learning_rate': 0.04980256651618988, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.776231653212487, 'colsample_bytree': 0.9921780493279373, 'colsample_bylevel': 0.7075409778363269, 'colsample_bynode': 0.6196255072669651, 'reg_alpha': 0.7914876877601625, 'reg_lambda': 0.6241212893912457, 'gamma': 0.4867930727848304, 'max_delta_step': 6, 'scale_pos_weight': 0.9741860907549074}. Best is trial 26 with value: 0.04473684929875273.
# [I 2025-11-21 14:36:39,615] Trial 32 finished with value: 0.061395802569170474 and parameters: {'max_bin': 357, 'learning_rate': 0.08493546241112741, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.829595320928527, 'colsample_bytree': 0.6366900546341427, 'colsample_bylevel': 0.47469570816129636, 'colsample_bynode': 0.6553469046474549, 'reg_alpha': 0.44179736223635024, 'reg_lambda': 0.5298073820135866, 'gamma': 0.4283391813119626, 'max_delta_step': 2, 'scale_pos_weight': 0.5105177231998685}. Best is trial 26 with value: 0.04473684929875273.
# [I 2025-11-21 14:36:41,957] Trial 28 finished with value: 0.046456581107147475 and parameters: {'max_bin': 196, 'learning_rate': 0.05060400105461098, 'max_depth': 10, 'min_child_weight': 3, 'subsample': 0.7815717050902996, 'colsample_bytree': 0.7703128733531894, 'colsample_bylevel': 0.6779843604842662, 'colsample_bynode': 0.6220256992591575, 'reg_alpha': 0.7927823208506543, 'reg_lambda': 0.40247821567570985, 'gamma': 0.4719719643068976, 'max_delta_step': 6, 'scale_pos_weight': 0.9928395211833909}. Best is trial 26 with value: 0.04473684929875273.
# [I 2025-11-21 14:36:44,081] Trial 25 finished with value: 0.04464411281094366 and parameters: {'max_bin': 185, 'learning_rate': 0.05015603495419922, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.7572594010975134, 'colsample_bytree': 0.9935392984901492, 'colsample_bylevel': 0.6861256965223516, 'colsample_bynode': 0.6244164927363232, 'reg_alpha': 0.7990229617024847, 'reg_lambda': 0.4465733814384252, 'gamma': 0.4333444943925701, 'max_delta_step': 6, 'scale_pos_weight': 0.9953308579825426}. Best is trial 25 with value: 0.04464411281094366.
# [I 2025-11-21 14:36:57,428] Trial 30 finished with value: 0.053649313726823834 and parameters: {'max_bin': 360, 'learning_rate': 0.049231351471098736, 'max_depth': 10, 'min_child_weight': 9, 'subsample': 0.8108126750325912, 'colsample_bytree': 0.6050151520733057, 'colsample_bylevel': 0.7013263011571041, 'colsample_bynode': 0.6057662163273829, 'reg_alpha': 0.43543316118235253, 'reg_lambda': 0.48473586480109265, 'gamma': 0.408564744884086, 'max_delta_step': 6, 'scale_pos_weight': 0.4878604344805733}. Best is trial 25 with value: 0.04464411281094366.
# [I 2025-11-21 14:37:00,859] Trial 36 finished with value: 0.10250161806968003 and parameters: {'max_bin': 244, 'learning_rate': 0.0383415998636216, 'max_depth': 6, 'min_child_weight': 3, 'subsample': 0.6669609122040777, 'colsample_bytree': 0.14038473985642974, 'colsample_bylevel': 0.4953491263270904, 'colsample_bynode': 0.6915348174613772, 'reg_alpha': 0.24202774193104715, 'reg_lambda': 0.5319059405148009, 'gamma': 0.8168493222987985, 'max_delta_step': 7, 'scale_pos_weight': 0.9986319501557357}. Best is trial 25 with value: 0.04464411281094366.
# [I 2025-11-21 14:37:46,936] Trial 35 finished with value: 0.048292225200164 and parameters: {'max_bin': 168, 'learning_rate': 0.03800722352027369, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.9952012262357145, 'colsample_bytree': 0.9958202469259717, 'colsample_bylevel': 0.4824953599046364, 'colsample_bynode': 0.6956251062353652, 'reg_alpha': 0.23169568909436228, 'reg_lambda': 0.47021559032226595, 'gamma': 0.7974646140630945, 'max_delta_step': 7, 'scale_pos_weight': 0.9905447234229432}. Best is trial 25 with value: 0.04464411281094366.
# [I 2025-11-21 14:37:49,024] Trial 33 finished with value: 0.04666915507388402 and parameters: {'max_bin': 185, 'learning_rate': 0.051296033147858584, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.9909340495718514, 'colsample_bytree': 0.6265161828032646, 'colsample_bylevel': 0.71981232790162, 'colsample_bynode': 0.658221397584472, 'reg_alpha': 0.42640226420106236, 'reg_lambda': 0.5015779386005076, 'gamma': 0.39837665635821257, 'max_delta_step': 6, 'scale_pos_weight': 0.9971656119963956}. Best is trial 25 with value: 0.04464411281094366.
# [I 2025-11-21 14:37:49,631] Trial 34 finished with value: 0.055395447848690306 and parameters: {'max_bin': 164, 'learning_rate': 0.0372236713878035, 'max_depth': 6, 'min_child_weight': 3, 'subsample': 0.9848184747137528, 'colsample_bytree': 0.6471654496766257, 'colsample_bylevel': 0.4881507577345483, 'colsample_bynode': 0.6850187126917929, 'reg_alpha': 0.4414610707675581, 'reg_lambda': 0.521877404364997, 'gamma': 0.10831198065868525, 'max_delta_step': 7, 'scale_pos_weight': 0.9911341392546601}. Best is trial 25 with value: 0.04464411281094366.
# [I 2025-11-21 14:37:59,712] Trial 41 finished with value: 0.04595038846262132 and parameters: {'max_bin': 165, 'learning_rate': 0.05644327414176761, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.9984083737400004, 'colsample_bytree': 0.9856155047690367, 'colsample_bylevel': 0.7849689761547324, 'colsample_bynode': 0.4073590765832001, 'reg_alpha': 0.36324525237337535, 'reg_lambda': 0.6787423841195604, 'gamma': 0.5658866934387666, 'max_delta_step': 7, 'scale_pos_weight': 0.9406890542855342}. Best is trial 25 with value: 0.04464411281094366.
# [I 2025-11-21 14:38:27,683] Trial 37 finished with value: 0.04502177082791498 and parameters: {'max_bin': 240, 'learning_rate': 0.037754727599429494, 'max_depth': 6, 'min_child_weight': 3, 'subsample': 0.9790166503134743, 'colsample_bytree': 0.9900812409010981, 'colsample_bylevel': 0.7676458360608929, 'colsample_bynode': 0.710408261605871, 'reg_alpha': 0.20875655751105104, 'reg_lambda': 0.6972913948651932, 'gamma': 0.563367381548784, 'max_delta_step': 7, 'scale_pos_weight': 0.9607994766383116}. Best is trial 25 with value: 0.04464411281094366.
# [I 2025-11-21 14:38:27,825] Trial 38 finished with value: 0.045114295850772576 and parameters: {'max_bin': 156, 'learning_rate': 0.03723385771702898, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.6938176915056804, 'colsample_bytree': 0.9978296436472831, 'colsample_bylevel': 0.7615890348444704, 'colsample_bynode': 0.7118854760616985, 'reg_alpha': 0.24762320006872984, 'reg_lambda': 0.5012243405759431, 'gamma': 0.5667493730430114, 'max_delta_step': 7, 'scale_pos_weight': 0.9203851967252087}. Best is trial 25 with value: 0.04464411281094366.
# [I 2025-11-21 14:38:36,085] Trial 39 finished with value: 0.04505722120123312 and parameters: {'max_bin': 233, 'learning_rate': 0.037530051903830096, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.6762601755580677, 'colsample_bytree': 0.9888508126883397, 'colsample_bylevel': 0.7649054737080181, 'colsample_bynode': 0.7219304913694896, 'reg_alpha': 0.2082332816638841, 'reg_lambda': 0.5319816260403258, 'gamma': 0.5697099173353197, 'max_delta_step': 7, 'scale_pos_weight': 0.9222023013684975}. Best is trial 25 with value: 0.04464411281094366.
# [I 2025-11-21 14:38:51,917] Trial 45 finished with value: 0.04852980627448357 and parameters: {'max_bin': 145, 'learning_rate': 0.06585177227741403, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.8669825454299891, 'colsample_bytree': 0.8480952019101915, 'colsample_bylevel': 0.7817895419529824, 'colsample_bynode': 0.4029523111814999, 'reg_alpha': 0.37355196409744146, 'reg_lambda': 0.5828109073374093, 'gamma': 0.5315709186685295, 'max_delta_step': 8, 'scale_pos_weight': 0.9144246621929107}. Best is trial 25 with value: 0.04464411281094366.
# [I 2025-11-21 14:38:59,106] Trial 43 finished with value: 0.04455319271045622 and parameters: {'max_bin': 148, 'learning_rate': 0.05745571569707586, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.697500324442396, 'colsample_bytree': 0.8383039656730589, 'colsample_bylevel': 0.7796241213941653, 'colsample_bynode': 0.7291604739787875, 'reg_alpha': 0.3818289598254372, 'reg_lambda': 0.5865023624877428, 'gamma': 0.7236331725198479, 'max_delta_step': 8, 'scale_pos_weight': 0.9257072634250231}. Best is trial 43 with value: 0.04455319271045622.
# [I 2025-11-21 14:38:59,358] Trial 42 finished with value: 0.04450299043182645 and parameters: {'max_bin': 134, 'learning_rate': 0.05775965212463949, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.673763766254859, 'colsample_bytree': 0.8382653507187187, 'colsample_bylevel': 0.7486335451268052, 'colsample_bynode': 0.7366006039464604, 'reg_alpha': 0.3759657056656333, 'reg_lambda': 0.682242784847678, 'gamma': 0.5724951065131273, 'max_delta_step': 8, 'scale_pos_weight': 0.9268922295548802}. Best is trial 42 with value: 0.04450299043182645.
# [I 2025-11-21 14:39:00,680] Trial 40 finished with value: 0.04528490934273797 and parameters: {'max_bin': 239, 'learning_rate': 0.03670855526346591, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.667108929535513, 'colsample_bytree': 0.9960579724746312, 'colsample_bylevel': 0.7869615594426067, 'colsample_bynode': 0.7222621954006414, 'reg_alpha': 0.2404349633043959, 'reg_lambda': 0.5545065418138709, 'gamma': 0.5856524077033536, 'max_delta_step': 7, 'scale_pos_weight': 0.9340622911219364}. Best is trial 42 with value: 0.04450299043182645.
# [I 2025-11-21 14:39:01,028] Trial 44 finished with value: 0.04448952801323756 and parameters: {'max_bin': 133, 'learning_rate': 0.05872130686065031, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.6919707432573554, 'colsample_bytree': 0.8637805100431776, 'colsample_bylevel': 0.7921716452005712, 'colsample_bynode': 0.8259017255220916, 'reg_alpha': 0.36490252024135394, 'reg_lambda': 0.5917738231288393, 'gamma': 0.5811317527909698, 'max_delta_step': 9, 'scale_pos_weight': 0.9150619930986873}. Best is trial 44 with value: 0.04448952801323756.
# [I 2025-11-21 14:39:44,848] Trial 46 finished with value: 0.04502638824526005 and parameters: {'max_bin': 134, 'learning_rate': 0.04328900286903064, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.6686059501329848, 'colsample_bytree': 0.8528822125208072, 'colsample_bylevel': 0.763663811638287, 'colsample_bynode': 0.8396139041119441, 'reg_alpha': 0.1667426778633342, 'reg_lambda': 0.35848434337526747, 'gamma': 0.5375516035978375, 'max_delta_step': 9, 'scale_pos_weight': 0.8943406082489138}. Best is trial 44 with value: 0.04448952801323756.
# [I 2025-11-21 14:39:54,800] Trial 53 finished with value: 0.044356759189738734 and parameters: {'max_bin': 134, 'learning_rate': 0.06678071130372108, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.6196113932541285, 'colsample_bytree': 0.8460181815438386, 'colsample_bylevel': 0.9833015497928412, 'colsample_bynode': 0.8339513184879384, 'reg_alpha': 0.9746840833220601, 'reg_lambda': 0.708532692152098, 'gamma': 0.3681597166657937, 'max_delta_step': 9, 'scale_pos_weight': 0.8705468747430791}. Best is trial 53 with value: 0.044356759189738734.
# [I 2025-11-21 14:40:24,184] Trial 51 finished with value: 0.04460007324983558 and parameters: {'max_bin': 136, 'learning_rate': 0.043638445557623876, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.6325095829185159, 'colsample_bytree': 0.8437241758120188, 'colsample_bylevel': 0.9696149892023048, 'colsample_bynode': 0.8299748530474875, 'reg_alpha': 0.755819603840566, 'reg_lambda': 0.7007302307935873, 'gamma': 0.7134030258391051, 'max_delta_step': 9, 'scale_pos_weight': 0.8685997363910006}. Best is trial 53 with value: 0.044356759189738734.
# [I 2025-11-21 14:40:30,742] Trial 50 finished with value: 0.04458225166026204 and parameters: {'max_bin': 218, 'learning_rate': 0.04269986424742254, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.5852376889612583, 'colsample_bytree': 0.8374758791281671, 'colsample_bylevel': 0.8228072000321974, 'colsample_bynode': 0.8274201604155373, 'reg_alpha': 0.11902343859407467, 'reg_lambda': 0.7099715738334615, 'gamma': 0.3366953592817171, 'max_delta_step': 9, 'scale_pos_weight': 0.8656314946132971}. Best is trial 53 with value: 0.044356759189738734.
# [I 2025-11-21 14:40:37,939] Trial 55 finished with value: 0.044810621289764804 and parameters: {'max_bin': 125, 'learning_rate': 0.0670461558105142, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.5567083902110658, 'colsample_bytree': 0.8278741750095686, 'colsample_bylevel': 0.8939114732673297, 'colsample_bynode': 0.8154672953401602, 'reg_alpha': 0.9879054951181678, 'reg_lambda': 0.739699213582252, 'gamma': 0.3535672891972465, 'max_delta_step': 9, 'scale_pos_weight': 0.881801893304372}. Best is trial 53 with value: 0.044356759189738734.
# [I 2025-11-21 14:40:42,195] Trial 54 finished with value: 0.04435411602253394 and parameters: {'max_bin': 118, 'learning_rate': 0.0680399980397254, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.5678914181911041, 'colsample_bytree': 0.8357484796412987, 'colsample_bylevel': 0.9973325698656592, 'colsample_bynode': 0.8260871768275172, 'reg_alpha': 0.3309161655884898, 'reg_lambda': 0.7223646166553945, 'gamma': 0.36723179917246396, 'max_delta_step': 9, 'scale_pos_weight': 0.8458353069254438}. Best is trial 54 with value: 0.04435411602253394.
# [I 2025-11-21 14:40:42,891] Trial 47 finished with value: 0.046145944598172846 and parameters: {'max_bin': 142, 'learning_rate': 0.032178331462019205, 'max_depth': 8, 'min_child_weight': 2, 'subsample': 0.5527456263917432, 'colsample_bytree': 0.8406939376525162, 'colsample_bylevel': 0.7531566548717546, 'colsample_bynode': 0.8162422328333934, 'reg_alpha': 0.12576324914132847, 'reg_lambda': 0.7152233049572561, 'gamma': 0.5578984230100464, 'max_delta_step': 8, 'scale_pos_weight': 0.8782185247245446}. Best is trial 54 with value: 0.04435411602253394.
# [I 2025-11-21 14:40:46,051] Trial 52 finished with value: 0.045768711295382535 and parameters: {'max_bin': 137, 'learning_rate': 0.03153274816686718, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.5773559389982674, 'colsample_bytree': 0.8480119789364726, 'colsample_bylevel': 0.9800500750413719, 'colsample_bynode': 0.8441272672185625, 'reg_alpha': 0.12143109184141343, 'reg_lambda': 0.7038664186518535, 'gamma': 0.7099650025832609, 'max_delta_step': 9, 'scale_pos_weight': 0.8682501576075373}. Best is trial 54 with value: 0.04435411602253394.
# [I 2025-11-21 14:41:05,007] Trial 49 finished with value: 0.04619686188952773 and parameters: {'max_bin': 222, 'learning_rate': 0.032816966675075526, 'max_depth': 8, 'min_child_weight': 2, 'subsample': 0.5591666208028552, 'colsample_bytree': 0.8637372496465342, 'colsample_bylevel': 0.737226637042636, 'colsample_bynode': 0.8299485529424904, 'reg_alpha': 0.17332102175720296, 'reg_lambda': 0.700588345217162, 'gamma': 0.5600268448250929, 'max_delta_step': 9, 'scale_pos_weight': 0.8764505230993977}. Best is trial 54 with value: 0.04435411602253394.
# [I 2025-11-21 14:41:09,969] Trial 48 finished with value: 0.04625781317071095 and parameters: {'max_bin': 221, 'learning_rate': 0.031873582854994656, 'max_depth': 8, 'min_child_weight': 2, 'subsample': 0.6845309750830296, 'colsample_bytree': 0.8659299132788429, 'colsample_bylevel': 0.7500833273447247, 'colsample_bynode': 0.8304587288980126, 'reg_alpha': 0.10664812254210583, 'reg_lambda': 0.6044337284126177, 'gamma': 0.5555731852179846, 'max_delta_step': 8, 'scale_pos_weight': 0.8861147193701359}. Best is trial 54 with value: 0.04435411602253394.
# [I 2025-11-21 14:41:12,809] Trial 56 finished with value: 0.044762047455431664 and parameters: {'max_bin': 116, 'learning_rate': 0.06877085829645857, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.555843791808644, 'colsample_bytree': 0.8401834810830755, 'colsample_bylevel': 0.9975565726612279, 'colsample_bynode': 0.8290780770342946, 'reg_alpha': 0.9888586044597714, 'reg_lambda': 0.7506847699405673, 'gamma': 0.8768426299132197, 'max_delta_step': 10, 'scale_pos_weight': 0.8634920719482765}. Best is trial 54 with value: 0.04435411602253394.
# [I 2025-11-21 14:41:20,455] Trial 57 finished with value: 0.044874400480974054 and parameters: {'max_bin': 112, 'learning_rate': 0.06437078375378064, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.5608377435766949, 'colsample_bytree': 0.7280073069927624, 'colsample_bylevel': 0.8918884123852505, 'colsample_bynode': 0.9265605093619529, 'reg_alpha': 0.1506325924543982, 'reg_lambda': 0.8127870736023612, 'gamma': 0.3459749698796434, 'max_delta_step': 9, 'scale_pos_weight': 0.8495379770962863}. Best is trial 54 with value: 0.04435411602253394.
# [I 2025-11-21 14:41:40,905] Trial 58 finished with value: 0.04463504294838366 and parameters: {'max_bin': 109, 'learning_rate': 0.06074898878138921, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.580476707703794, 'colsample_bytree': 0.7150383021574, 'colsample_bylevel': 0.9706110114477041, 'colsample_bynode': 0.9033647837178618, 'reg_alpha': 0.3301577092364476, 'reg_lambda': 0.7940016200514548, 'gamma': 0.7193918980854376, 'max_delta_step': 9, 'scale_pos_weight': 0.864232606302211}. Best is trial 54 with value: 0.04435411602253394.
# [I 2025-11-21 14:41:43,540] Trial 60 finished with value: 0.0443642707871184 and parameters: {'max_bin': 121, 'learning_rate': 0.07771279638477248, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.581585046887381, 'colsample_bytree': 0.7172936955474583, 'colsample_bylevel': 0.9563347130261858, 'colsample_bynode': 0.9073079651544304, 'reg_alpha': 0.31972492502259886, 'reg_lambda': 0.8153518096865666, 'gamma': 0.341520535115312, 'max_delta_step': 10, 'scale_pos_weight': 0.840716951185245}. Best is trial 54 with value: 0.04435411602253394.
# [I 2025-11-21 14:41:49,421] Trial 59 finished with value: 0.044324049267978054 and parameters: {'max_bin': 101, 'learning_rate': 0.06084746430465237, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.5878566514391752, 'colsample_bytree': 0.8826798735011053, 'colsample_bylevel': 0.9792780101748879, 'colsample_bynode': 0.8891636002999334, 'reg_alpha': 0.3282845162862301, 'reg_lambda': 0.7473118707345314, 'gamma': 0.36869777345546734, 'max_delta_step': 10, 'scale_pos_weight': 0.8588857587700972}. Best is trial 59 with value: 0.044324049267978054.
# [I 2025-11-21 14:41:56,422] Trial 61 finished with value: 0.04484915413473699 and parameters: {'max_bin': 110, 'learning_rate': 0.06865462925928248, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.4861708751627001, 'colsample_bytree': 0.7053529633996249, 'colsample_bylevel': 0.821315428931906, 'colsample_bynode': 0.7663307727704802, 'reg_alpha': 0.325109646666788, 'reg_lambda': 0.7992123788888483, 'gamma': 0.3425365013519189, 'max_delta_step': 10, 'scale_pos_weight': 0.3854151552541246}. Best is trial 59 with value: 0.044324049267978054.
# [I 2025-11-21 14:42:06,123] Trial 62 finished with value: 0.044478926915188476 and parameters: {'max_bin': 108, 'learning_rate': 0.0788200318592775, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.5110074909695312, 'colsample_bytree': 0.7170785706423695, 'colsample_bylevel': 0.8176119395538314, 'colsample_bynode': 0.9158803785198725, 'reg_alpha': 0.3218007957320006, 'reg_lambda': 0.7695841199076862, 'gamma': 0.32914211248356096, 'max_delta_step': 10, 'scale_pos_weight': 0.6891605443726913}. Best is trial 59 with value: 0.044324049267978054.
# [I 2025-11-21 14:42:19,510] Trial 63 finished with value: 0.044383314389077784 and parameters: {'max_bin': 109, 'learning_rate': 0.07760133753271956, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.5104191772891185, 'colsample_bytree': 0.7245046245975572, 'colsample_bylevel': 0.9401317488236774, 'colsample_bynode': 0.9173075490799303, 'reg_alpha': 0.34229076614534243, 'reg_lambda': 0.7987370127105271, 'gamma': 0.3349484375690509, 'max_delta_step': 10, 'scale_pos_weight': 0.7836104340770109}. Best is trial 59 with value: 0.044324049267978054.
# [I 2025-11-21 14:42:20,026] Trial 64 finished with value: 0.04445937296760526 and parameters: {'max_bin': 105, 'learning_rate': 0.07729211267070388, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.502725045477178, 'colsample_bytree': 0.7170932955581251, 'colsample_bylevel': 0.8235834569194358, 'colsample_bynode': 0.9066188404357348, 'reg_alpha': 0.31890868222911267, 'reg_lambda': 0.8032592407717744, 'gamma': 0.32288923242529133, 'max_delta_step': 10, 'scale_pos_weight': 0.6942414066933498}. Best is trial 59 with value: 0.044324049267978054.
# [I 2025-11-21 14:42:28,318] Trial 65 finished with value: 0.0444620195491277 and parameters: {'max_bin': 453, 'learning_rate': 0.07971021069753755, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.4905743786675417, 'colsample_bytree': 0.6859433301950857, 'colsample_bylevel': 0.8149348383226045, 'colsample_bynode': 0.8794920311322659, 'reg_alpha': 0.2992898942989483, 'reg_lambda': 0.8141290651139118, 'gamma': 0.25387149351188876, 'max_delta_step': 10, 'scale_pos_weight': 0.3583470366159973}. Best is trial 59 with value: 0.044324049267978054.
# [I 2025-11-21 14:42:43,446] Trial 66 finished with value: 0.044498173303448234 and parameters: {'max_bin': 101, 'learning_rate': 0.07833748861366928, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.4752711813256424, 'colsample_bytree': 0.916188379196889, 'colsample_bylevel': 0.8303003923454959, 'colsample_bynode': 0.7556753618868807, 'reg_alpha': 0.2744125690405196, 'reg_lambda': 0.8479475711443566, 'gamma': 0.3287272097045499, 'max_delta_step': 10, 'scale_pos_weight': 0.7864166395964927}. Best is trial 59 with value: 0.044324049267978054.
# [I 2025-11-21 14:42:44,008] Trial 67 finished with value: 0.04430564433455759 and parameters: {'max_bin': 474, 'learning_rate': 0.08067873215427879, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.49924503689289274, 'colsample_bytree': 0.9362011431201858, 'colsample_bylevel': 0.9401434597638324, 'colsample_bynode': 0.7792552996761218, 'reg_alpha': 0.28670723275948345, 'reg_lambda': 0.8512041849936365, 'gamma': 0.18871379385185721, 'max_delta_step': 10, 'scale_pos_weight': 0.7085863439051923}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:42:53,400] Trial 68 finished with value: 0.04434653002924232 and parameters: {'max_bin': 454, 'learning_rate': 0.07868066340627314, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.5040315194147441, 'colsample_bytree': 0.9479667770462583, 'colsample_bylevel': 0.9430552283301779, 'colsample_bynode': 0.7655122726336892, 'reg_alpha': 0.39552300240175564, 'reg_lambda': 0.8733811160838869, 'gamma': 0.24608149022741396, 'max_delta_step': 10, 'scale_pos_weight': 0.6713110796466873}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:43:07,478] Trial 73 finished with value: 0.04559451937312371 and parameters: {'max_bin': 511, 'learning_rate': 0.0793064031560927, 'max_depth': 2, 'min_child_weight': 1, 'subsample': 0.44129840298133716, 'colsample_bytree': 0.6775560086321681, 'colsample_bylevel': 0.9419895517162508, 'colsample_bynode': 0.8794871910976889, 'reg_alpha': 0.2792005950476353, 'reg_lambda': 0.8474441442327201, 'gamma': 0.23744259849452945, 'max_delta_step': 10, 'scale_pos_weight': 0.7869371131680077}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:43:08,638] Trial 70 finished with value: 0.04439970942699668 and parameters: {'max_bin': 483, 'learning_rate': 0.07454488518529565, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.4190405553658939, 'colsample_bytree': 0.9301099102791999, 'colsample_bylevel': 0.934814454111191, 'colsample_bynode': 0.8778030708131037, 'reg_alpha': 0.2826078898263108, 'reg_lambda': 0.6552478508436457, 'gamma': 0.2523061506657835, 'max_delta_step': 10, 'scale_pos_weight': 0.7877524085100726}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:43:09,611] Trial 69 finished with value: 0.044366179569042354 and parameters: {'max_bin': 497, 'learning_rate': 0.07830766821878586, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.42681318819587055, 'colsample_bytree': 0.9495501827491015, 'colsample_bylevel': 0.929268591904208, 'colsample_bynode': 0.8705159116539275, 'reg_alpha': 0.28313939524035914, 'reg_lambda': 0.6567441531297524, 'gamma': 0.2116059505700588, 'max_delta_step': 10, 'scale_pos_weight': 0.6685159363725606}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:43:21,538] Trial 74 finished with value: 0.045309150836721934 and parameters: {'max_bin': 499, 'learning_rate': 0.0774381801343919, 'max_depth': 2, 'min_child_weight': 1, 'subsample': 0.42722327956014977, 'colsample_bytree': 0.9393888508856821, 'colsample_bylevel': 0.9392321697206765, 'colsample_bynode': 0.9946585603160686, 'reg_alpha': 0.29171073416063054, 'reg_lambda': 0.9206336075908662, 'gamma': 0.2399764454088644, 'max_delta_step': 10, 'scale_pos_weight': 0.690030802324892}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:43:22,029] Trial 75 finished with value: 0.04534648808658601 and parameters: {'max_bin': 524, 'learning_rate': 0.07680362508423923, 'max_depth': 2, 'min_child_weight': 1, 'subsample': 0.4008104980651681, 'colsample_bytree': 0.9402374062387551, 'colsample_bylevel': 0.9426817968564319, 'colsample_bynode': 0.9928428811316057, 'reg_alpha': 0.28072148157257804, 'reg_lambda': 0.9013680389374391, 'gamma': 0.15125519085803682, 'max_delta_step': 10, 'scale_pos_weight': 0.6886161176288708}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:43:28,822] Trial 71 finished with value: 0.044405056738414835 and parameters: {'max_bin': 102, 'learning_rate': 0.0784450014106283, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.4212530670426136, 'colsample_bytree': 0.9336736583844341, 'colsample_bylevel': 0.9324492072485133, 'colsample_bynode': 0.9995670308480309, 'reg_alpha': 0.2988671262582781, 'reg_lambda': 0.8727772463323336, 'gamma': 0.2453436633694579, 'max_delta_step': 10, 'scale_pos_weight': 0.6683903049919483}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:43:31,324] Trial 76 finished with value: 0.04509791354394951 and parameters: {'max_bin': 500, 'learning_rate': 0.08306823166405672, 'max_depth': 2, 'min_child_weight': 1, 'subsample': 0.37620832197974563, 'colsample_bytree': 0.9475452427710327, 'colsample_bylevel': 0.9414869080754994, 'colsample_bynode': 0.9975175260907966, 'reg_alpha': 0.9393996416677453, 'reg_lambda': 0.928900755409559, 'gamma': 0.18214109221814542, 'max_delta_step': 10, 'scale_pos_weight': 0.658252260808514}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:43:32,350] Trial 72 finished with value: 0.04438022516193784 and parameters: {'max_bin': 100, 'learning_rate': 0.07766364127154933, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.4267825350098213, 'colsample_bytree': 0.6801796608780347, 'colsample_bylevel': 0.9459189150944545, 'colsample_bynode': 0.9873550616048269, 'reg_alpha': 0.2905835733751749, 'reg_lambda': 0.8599250242930981, 'gamma': 0.2399661133668376, 'max_delta_step': 10, 'scale_pos_weight': 0.6643854871009015}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:43:47,659] Trial 77 finished with value: 0.04514102624132919 and parameters: {'max_bin': 446, 'learning_rate': 0.08172572546736577, 'max_depth': 2, 'min_child_weight': 1, 'subsample': 0.3777726699690268, 'colsample_bytree': 0.951822577761421, 'colsample_bylevel': 0.9385484655363472, 'colsample_bynode': 0.999810620063054, 'reg_alpha': 0.919340732808295, 'reg_lambda': 0.9016848164552755, 'gamma': 0.18396257411752465, 'max_delta_step': 10, 'scale_pos_weight': 0.6592846509387857}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:43:54,434] Trial 79 finished with value: 0.04496267468522266 and parameters: {'max_bin': 459, 'learning_rate': 0.0937032678283897, 'max_depth': 2, 'min_child_weight': 1, 'subsample': 0.3999623093956113, 'colsample_bytree': 0.9533406581009597, 'colsample_bylevel': 0.8839903041540615, 'colsample_bynode': 0.9576622014473161, 'reg_alpha': 0.4050440176555693, 'reg_lambda': 0.9128027880268005, 'gamma': 0.1769490392973761, 'max_delta_step': 10, 'scale_pos_weight': 0.6445780468951291}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:44:11,284] Trial 81 finished with value: 0.04462911836401544 and parameters: {'max_bin': 446, 'learning_rate': 0.08302084396011666, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.3361724095151649, 'colsample_bytree': 0.9543984122668967, 'colsample_bylevel': 0.8876236032179624, 'colsample_bynode': 0.9552631576250937, 'reg_alpha': 0.39925488270587556, 'reg_lambda': 0.7362407130483298, 'gamma': 0.38264411175790214, 'max_delta_step': 10, 'scale_pos_weight': 0.6383399772996176}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:44:11,877] Trial 78 finished with value: 0.044352821866857746 and parameters: {'max_bin': 452, 'learning_rate': 0.08280608172948659, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.37591492545385374, 'colsample_bytree': 0.951487271789404, 'colsample_bylevel': 0.9388637054229773, 'colsample_bynode': 0.9604083459403605, 'reg_alpha': 0.4041429924038189, 'reg_lambda': 0.9051776881758105, 'gamma': 0.1853792547587375, 'max_delta_step': 10, 'scale_pos_weight': 0.721182363183059}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:44:12,739] Trial 80 finished with value: 0.044492030461965384 and parameters: {'max_bin': 568, 'learning_rate': 0.08327029120589317, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.3810368780672238, 'colsample_bytree': 0.9514233615965153, 'colsample_bylevel': 0.890267203370201, 'colsample_bynode': 0.9532919144435346, 'reg_alpha': 0.3874721821196441, 'reg_lambda': 0.8874390394295785, 'gamma': 0.19195929628501177, 'max_delta_step': 10, 'scale_pos_weight': 0.6463297409697158}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:44:20,526] Trial 83 finished with value: 0.0446003342692855 and parameters: {'max_bin': 413, 'learning_rate': 0.09048998320477686, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.5275954754497225, 'colsample_bytree': 0.8094841175914429, 'colsample_bylevel': 0.86759951291193, 'colsample_bynode': 0.8554817698338355, 'reg_alpha': 0.3911925314498809, 'reg_lambda': 0.7365883924191605, 'gamma': 0.20555748248207736, 'max_delta_step': 9, 'scale_pos_weight': 0.7410085883674163}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:44:26,213] Trial 82 finished with value: 0.044559629736313874 and parameters: {'max_bin': 431, 'learning_rate': 0.08177819284050741, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.5262176502849978, 'colsample_bytree': 0.8904374437344105, 'colsample_bylevel': 0.8738036377536836, 'colsample_bynode': 0.9569448414489151, 'reg_alpha': 0.34079776198869693, 'reg_lambda': 0.7815713555470252, 'gamma': 0.19053064104188472, 'max_delta_step': 9, 'scale_pos_weight': 0.6415659727209007}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:44:28,026] Trial 84 finished with value: 0.044664230323831045 and parameters: {'max_bin': 455, 'learning_rate': 0.0709965481514348, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.300354992070492, 'colsample_bytree': 0.8907346139035538, 'colsample_bylevel': 0.8865174193929444, 'colsample_bynode': 0.9502786069261387, 'reg_alpha': 0.3944007639074037, 'reg_lambda': 0.9534912333443517, 'gamma': 0.20187493437020937, 'max_delta_step': 9, 'scale_pos_weight': 0.5836794211021346}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:44:39,755] Trial 85 finished with value: 0.04461553230177483 and parameters: {'max_bin': 551, 'learning_rate': 0.09039752309035386, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.6169260640675055, 'colsample_bytree': 0.8905829306330747, 'colsample_bylevel': 0.8771365153075458, 'colsample_bynode': 0.9422189261741538, 'reg_alpha': 0.3930181342044568, 'reg_lambda': 0.867358909097891, 'gamma': 0.3819752127480053, 'max_delta_step': 9, 'scale_pos_weight': 0.6010062584634638}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:44:52,800] Trial 86 finished with value: 0.04485892531074538 and parameters: {'max_bin': 435, 'learning_rate': 0.07059945856978198, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.5249255537110167, 'colsample_bytree': 0.7983133500635993, 'colsample_bylevel': 0.8603608803395058, 'colsample_bynode': 0.7867673054541832, 'reg_alpha': 0.40159190142981877, 'reg_lambda': 0.8617213174645251, 'gamma': 0.2958048710989872, 'max_delta_step': 9, 'scale_pos_weight': 0.5959764525821091}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:45:00,632] Trial 88 finished with value: 0.04455002549113043 and parameters: {'max_bin': 418, 'learning_rate': 0.0912503589612526, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.45517296076857056, 'colsample_bytree': 0.8915213834801854, 'colsample_bylevel': 0.9994379067683595, 'colsample_bynode': 0.793994767968081, 'reg_alpha': 0.4656836132291772, 'reg_lambda': 0.9439501508427932, 'gamma': 0.210902582179761, 'max_delta_step': 9, 'scale_pos_weight': 0.582490432561402}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:45:01,322] Trial 89 finished with value: 0.04466713517023475 and parameters: {'max_bin': 474, 'learning_rate': 0.08912430749252907, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.3220448341734693, 'colsample_bytree': 0.7997371436580746, 'colsample_bylevel': 0.9979184172685845, 'colsample_bynode': 0.7837151481282002, 'reg_alpha': 0.21022332759120566, 'reg_lambda': 0.950098002573604, 'gamma': 0.2893215138016142, 'max_delta_step': 9, 'scale_pos_weight': 0.7336538897749407}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:45:02,498] Trial 87 finished with value: 0.04479910778666191 and parameters: {'max_bin': 564, 'learning_rate': 0.07165633381936708, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.5291768818123767, 'colsample_bytree': 0.7964870715927933, 'colsample_bylevel': 0.8576052921418862, 'colsample_bynode': 0.7876637087481778, 'reg_alpha': 0.20932678863435458, 'reg_lambda': 0.9402192258016385, 'gamma': 0.2968541937161467, 'max_delta_step': 9, 'scale_pos_weight': 0.5975671040078503}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:45:17,274] Trial 90 finished with value: 0.044403548565907856 and parameters: {'max_bin': 481, 'learning_rate': 0.0885703603850583, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.32111211172493026, 'colsample_bytree': 0.8895961628770482, 'colsample_bylevel': 0.9123162224565244, 'colsample_bynode': 0.8583860330355696, 'reg_alpha': 0.34823401957081074, 'reg_lambda': 0.9985653274296539, 'gamma': 0.2866949513627795, 'max_delta_step': 9, 'scale_pos_weight': 0.6142054565707689}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:45:32,913] Trial 91 finished with value: 0.046098271688520154 and parameters: {'max_bin': 384, 'learning_rate': 0.0709554842012741, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.6379305761975572, 'colsample_bytree': 0.5754809428624402, 'colsample_bylevel': 0.9962799438623521, 'colsample_bynode': 0.786339612070714, 'reg_alpha': 0.21727592387693972, 'reg_lambda': 0.9606644446664615, 'gamma': 0.13875920897687047, 'max_delta_step': 9, 'scale_pos_weight': 0.7207518333580464}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:45:36,482] Trial 92 finished with value: 0.04436506590987175 and parameters: {'max_bin': 327, 'learning_rate': 0.07119094692321525, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.46192641977680804, 'colsample_bytree': 0.7992134084674287, 'colsample_bylevel': 0.9961354249706627, 'colsample_bynode': 0.7769749684560145, 'reg_alpha': 0.18945736426342794, 'reg_lambda': 0.8736867188866878, 'gamma': 0.2904978440137568, 'max_delta_step': 9, 'scale_pos_weight': 0.7179146978103812}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:45:45,001] Trial 95 finished with value: 0.06347420146190974 and parameters: {'max_bin': 473, 'learning_rate': 0.07432883946265696, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.589434753946497, 'colsample_bytree': 0.9101598580526471, 'colsample_bylevel': 0.9169215384504296, 'colsample_bynode': 0.20956641526430342, 'reg_alpha': 0.1984094004663292, 'reg_lambda': 0.838448952602054, 'gamma': 0.13571106746214714, 'max_delta_step': 10, 'scale_pos_weight': 0.7171622936364387}. Best is trial 67 with value: 0.04430564433455759.
# [I 2025-11-21 14:45:50,839] Trial 93 finished with value: 0.044209887462535694 and parameters: {'max_bin': 476, 'learning_rate': 0.07187305692574249, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.6355182760096784, 'colsample_bytree': 0.9074287439998969, 'colsample_bylevel': 0.9981611485228856, 'colsample_bynode': 0.7882457552260996, 'reg_alpha': 0.2081067667203366, 'reg_lambda': 0.8304066349591137, 'gamma': 0.14254236576382884, 'max_delta_step': 0, 'scale_pos_weight': 0.7186324208830611}. Best is trial 93 with value: 0.044209887462535694.
# [I 2025-11-21 14:45:56,439] Trial 97 finished with value: 0.044657844413133134 and parameters: {'max_bin': 398, 'learning_rate': 0.07456653080043664, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.6263537916442087, 'colsample_bytree': 0.5691961203439493, 'colsample_bylevel': 0.9125709801140544, 'colsample_bynode': 0.8584860375526564, 'reg_alpha': 0.2610218844045554, 'reg_lambda': 0.8308925725311906, 'gamma': 0.14396708982643733, 'max_delta_step': 10, 'scale_pos_weight': 0.8368830972296405}. Best is trial 93 with value: 0.044209887462535694.
# [I 2025-11-21 14:45:58,353] Trial 96 finished with value: 0.04428004871990195 and parameters: {'max_bin': 378, 'learning_rate': 0.07444116815865982, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.46123270673644107, 'colsample_bytree': 0.7590316294546617, 'colsample_bylevel': 0.9111968086372817, 'colsample_bynode': 0.86184389478158, 'reg_alpha': 0.36286728142235375, 'reg_lambda': 0.829709468114601, 'gamma': 0.13452547648609825, 'max_delta_step': 0, 'scale_pos_weight': 0.7590447812415937}. Best is trial 93 with value: 0.044209887462535694.
# [I 2025-11-21 14:45:59,429] Trial 94 finished with value: 0.04421504751855472 and parameters: {'max_bin': 470, 'learning_rate': 0.07491664827862272, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.6358421181159709, 'colsample_bytree': 0.8795997176838712, 'colsample_bylevel': 0.9976404465736721, 'colsample_bynode': 0.7966221421500732, 'reg_alpha': 0.4735968010600313, 'reg_lambda': 0.9981013401644898, 'gamma': 0.14345703174518526, 'max_delta_step': 0, 'scale_pos_weight': 0.7229071580701614}. Best is trial 93 with value: 0.044209887462535694.
# [I 2025-11-21 14:46:01,389] Trial 98 finished with value: 0.04473234759918066 and parameters: {'max_bin': 334, 'learning_rate': 0.07485024855057056, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.46156511943056683, 'colsample_bytree': 0.5735594822798271, 'colsample_bylevel': 0.9613706851993675, 'colsample_bynode': 0.9076284380524816, 'reg_alpha': 0.5540301699479178, 'reg_lambda': 0.8283004605024549, 'gamma': 0.13702815046464775, 'max_delta_step': 10, 'scale_pos_weight': 0.7091825610652069}. Best is trial 93 with value: 0.044209887462535694.
# [I 2025-11-21 14:46:05,142] Trial 99 finished with value: 0.044324846313671236 and parameters: {'max_bin': 123, 'learning_rate': 0.08588923330437515, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.6064243168098725, 'colsample_bytree': 0.7460043389464662, 'colsample_bylevel': 0.964320297600564, 'colsample_bynode': 0.9328639276709864, 'reg_alpha': 0.25348231054418935, 'reg_lambda': 0.8327276045015675, 'gamma': 0.270443849835602, 'max_delta_step': 10, 'scale_pos_weight': 0.8441370120482031}. Best is trial 93 with value: 0.044209887462535694.

# %% [markdown]
# stratified k-fold

# %%
#use 7 fold
FOLD = 7

# %%
#stratification bins
#In practice, many data scientists use standard K-fold for regression first, 
# and only implement binned stratification if the results show high variance across folds 
# or if the target distribution is highly imbalanced.
#q=10 best practice, and must be q > k.(q  = 10 must be larger than k = 7 fold)
#this q will also have positive relationship with data,if data is large q also should be increased

y_bins = pd.qcut(y_train,q=10,labels=False,duplicates='drop')

# %%
skf = StratifiedKFold(n_splits=FOLD,shuffle=True,random_state=42)
fold_splits = list(skf.split(X_train,y_bins))

# %%
oof_prediction = np.zeros(len(X_train))
test_prediction = np.zeros(len(X_test))

fold_scores = []
# feature_importance_dict = {}

# %%
for fold,(train_idx,val_idx) in enumerate(fold_splits,1):
    print(f'Fold {fold}/{FOLD}')

    X_tr,X_val = X_train.iloc[train_idx],X_train.iloc[val_idx]
    y_tr,y_val = y_train.iloc[train_idx],y_train.iloc[val_idx]

    dtrain = xgb.DMatrix(X_tr,label=y_tr)
    dval = xgb.DMatrix(X_val,label=y_val)
    dtest = xgb.DMatrix(X_test)

    model = xgb.train(
        params = study.best_params,
        dtrain = dtrain,
        num_boost_round = 10000,
        evals = [(dval,'valid')],
        early_stopping_rounds = 200,
        verbose_eval = False
    )

    oof_prediction[val_idx] = model.predict(dval)
    test_prediction += model.predict(dtest)

    fold_rmse = np.sqrt(np.mean((oof_prediction[val_idx] - y_val)**2))
    fold_scores.append(fold_rmse)
    print(f'FOLD {fold} RMSE:{fold_rmse:.6f}')

test_prediction/=FOLD
# Out:
# Fold 1/7
# FOLD 1 RMSE:0.056891
# Fold 2/7
# FOLD 2 RMSE:0.056377
# Fold 3/7
# FOLD 3 RMSE:0.056583
# Fold 4/7
# FOLD 4 RMSE:0.056338
# Fold 5/7
# FOLD 5 RMSE:0.057080
# Fold 6/7
# FOLD 6 RMSE:0.056789
# Fold 7/7
# FOLD 7 RMSE:0.056808

# %%
print(test_prediction)
# Out:
# [0.29255874 0.12861986 0.19046778 ... 0.24955629 0.13232968 0.48761022]
